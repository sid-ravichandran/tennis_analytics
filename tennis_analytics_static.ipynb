# %% [markdown]
# ## Source Dataset
#
# I found a decent tennis dataset with matches and player data for both the ATP and WTA, covering the years from 1950 to 2021
# https://www.kaggle.com/datasets/taylorbrownlow/atpwta-tennis-data?resource=download&select=KaggleMatches.csv
#
# I've created functions for the analysis below and applied it to some examples. Feel free to apply it to your own players or tournaments!
#
# #### Contents:
# * [Dataset Exploration](#1-bullet)
# * [Find tournament winner for a given year](#2-bullet)
#     * [Who won the Barcelona Open in 2010?](#21-bullet)
# * [Find titles won by a player](#3-bullet)
#     * [Which titles has Fernando Verdasco won?](#31-bullet)
# * [Let's analyse some famous head-to-heads!](#4-bullet)
#     * [Federer v/s Nadal](#5-bullet)
#     * [Nadal v/s Djokovic](#6-bullet)
#     * [Sampras v/s Agassi](#7-bullet)
# * [Let's track player's rank through the years!](#8-bullet)
#     * [The big 3!](#81-bullet)
#     * [The 90s superstars!](#82-bullet)
# * [Which major tournaments are the most and least upset prone?](#9-bullet)
#     * [Grand Slams](#91-bullet)
#     * [Master's 1000's](#92-bullet)
# * [Tennis player analysis](#10-bullet)
#     * [Tennis player feature engineering](#1005-bullet)
#     * [Male players: Titles vs Finals](#101-bullet)
#     * [Male players: Best Grand Slam performers](#102-bullet)
#     * [Male players: Best Hard Court performers](#103-bullet)
#     * [Male players: Best Clay Court performers](#104-bullet)
#     * [Male players: Best Grass Court performers](#105-bullet)
#     * [Male players: Best Carpet Court performers](#106-bullet)
#     * [Male players: Hard vs Clay court performers](#107-bullet)
#     * [Male players: Hard vs Grass court performers](#108-bullet)
#     * [Male players: Grass vs Clay court performers](#109-bullet)
#     * [Quasi Simpson Paradox](#110-bullet)
#     * [Best Male Players not to have won a Grand Slam](#111-bullet)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_context('notebook', font_scale=1.15)

# %%
pd.set_option('display.max_columns', None)
pd.options.mode.chained_assignment = None

# %%
import plotly.io as pio
pio.renderers.default='notebook'
import plotly.express as px

# %% [markdown]
# ## Dataset Exploration <a class="anchor" id="1-bullet"></a>

# %%
# Matches database
df_matches = pd.read_csv(r'C:\Users\slaye\Desktop\Python\Tennis\KaggleMatches.csv')
df_matches.head(5)
# Out:
# C:\Users\slaye\AppData\Local\Temp\ipykernel_32384\3804434625.py:2: DtypeWarning:
#
# Columns (3,8,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   tourney_id tourney_name surface draw_size tourney_level tourney_date  \
# 0  2019-M020     Brisbane    Hard        32             A   2018-12-31
# 1  2019-M020     Brisbane    Hard        32             A   2018-12-31
# 2  2019-M020     Brisbane    Hard        32             A   2018-12-31
# 3  2019-M020     Brisbane    Hard        32             A   2018-12-31
# 4  2019-M020     Brisbane    Hard        32             A   2018-12-31
#
#    match_num  winner_id winner_seed winner_entry         winner_name  \
# 0        300     105453         2.0          NaN       Kei Nishikori
# 1        299     106421         4.0          NaN     Daniil Medvedev
# 2        298     105453         2.0          NaN       Kei Nishikori
# 3        297     104542         NaN           PR  Jo-Wilfried Tsonga
# 4        296     106421         4.0          NaN     Daniil Medvedev
#
#   winner_hand  winner_ht winner_ioc  winner_age  loser_id loser_seed  \
# 0           R      178.0        JPN   29.004791    106421        4.0
# 1           R        NaN        RUS   22.885695    104542        NaN
# 2           R      178.0        JPN   29.004791    104871        NaN
# 3           R      188.0        FRA   33.705681    200282        7.0
# 4           R        NaN        RUS   22.885695    105683        5.0
#
#   loser_entry          loser_name loser_hand  loser_ht loser_ioc  loser_age  \
# 0         NaN     Daniil Medvedev          R       NaN       RUS  22.885695
# 1          PR  Jo-Wilfried Tsonga          R     188.0       FRA  33.705681
# 2         NaN       Jeremy Chardy          R     188.0       FRA  31.882272
# 3         NaN      Alex De Minaur          R       NaN       AUS  19.868583
# 4         NaN        Milos Raonic          R     196.0       CAN  28.010951
#
#             score  best_of round  minutes  w_ace  w_df  w_svpt  w_1stIn  \
# 0     6-4 3-6 6-2        3     F    124.0    3.0   3.0    77.0     44.0
# 1      7-6(6) 6-2        3    SF     82.0   10.0   1.0    52.0     33.0
# 2         6-2 6-2        3    SF     66.0    2.0   2.0    47.0     33.0
# 3      6-4 7-6(2)        3    QF    106.0   12.0   2.0    68.0     43.0
# 4  6-7(2) 6-3 6-4        3    QF    129.0   12.0   3.0   105.0     68.0
#
#    w_1stWon  w_2ndWon  w_SvGms  w_bpSaved  w_bpFaced  l_ace  l_df  l_svpt  \
# 0      31.0      17.0     13.0        3.0        6.0    8.0   6.0   100.0
# 1      28.0      14.0     10.0        0.0        1.0   17.0   2.0    77.0
# 2      26.0       9.0      8.0        2.0        2.0   10.0   3.0    46.0
# 3      34.0      15.0     11.0        4.0        5.0    1.0   2.0    81.0
# 4      48.0      25.0     16.0        8.0        8.0   29.0   5.0    94.0
#
#    l_1stIn  l_1stWon  l_2ndWon  l_SvGms  l_bpSaved  l_bpFaced  winner_rank  \
# 0     54.0      34.0      20.0     14.0       10.0       15.0          9.0
# 1     52.0      36.0       7.0     10.0       10.0       13.0         16.0
# 2     27.0      15.0       6.0      8.0        1.0        5.0          9.0
# 3     60.0      38.0       9.0     11.0        4.0        6.0        239.0
# 4     56.0      46.0      19.0     15.0        2.0        4.0         16.0
#
#    winner_rank_points  loser_rank  loser_rank_points league
# 0              3590.0        16.0             1977.0    atp
# 1              1977.0       239.0              200.0    atp
# 2              3590.0        40.0             1050.0    atp
# 3               200.0        31.0             1298.0    atp
# 4              1977.0        18.0             1855.0    atp

# %%
# Create columns for day, month, year of match
df_matches['tourney_date'] = pd.to_datetime(df_matches['tourney_date'])

df_matches['year'] = df_matches['tourney_date'].dt.year
df_matches['month'] = df_matches['tourney_date'].dt.month
df_matches['day'] = df_matches['tourney_date'].dt.day

# %%
# Extents of matches
print(f'First match in dataset: {df_matches["tourney_date"].min()}')
print(f'Last match in dataset: {df_matches["tourney_date"].max()}')
# Out:
# First match in dataset: 1949-12-22 00:00:00
# Last match in dataset: 2021-02-22 00:00:00

# %%
# Players dataset
df_players = pd.read_csv(r'C:\Users\slaye\Desktop\Python\Tennis\KagglePlayers.csv')
df_players.head(5)
# Out:
#    player_id      name_first name_last hand   birthdate country gender
# 0     100001         Gardnar    Mulloy    R  19131122.0     USA   male
# 1     100002          Pancho    Segura    R  19210620.0     ECU   male
# 2     100003           Frank   Sedgman    R  19271002.0     AUS   male
# 3     100004        Giuseppe     Merlo    R  19271011.0     ITA   male
# 4     100005  Richard Pancho  Gonzales    R  19280509.0     USA   male

# %%
# The birthdate column is not well formatted
df_players_cleaned = df_players[~pd.isnull(df_players['birthdate'])]
df_players_cleaned.loc[:, 'birth_year'] = df_players_cleaned['birthdate'].apply(lambda x:int(str(x)[0:4]))

print('Oldest Players in dataset:')
display(df_players_cleaned[df_players_cleaned['birth_year']==df_players_cleaned['birth_year'].min()])

print('Youngest Players in dataset:')
display(df_players_cleaned[df_players_cleaned['birth_year']==df_players_cleaned['birth_year'].max()])

# create a column for league
df_players_cleaned.loc[:, 'league'] = df_players_cleaned['gender'].apply(lambda x:'atp' if x=='male' else 'wta')
# Out:
# Oldest Players in dataset:
#        player_id  name_first name_last hand   birthdate country gender  \
# 14626     114642  John Henry     Lewis  NaN  18340000.0     GBR   male
#
#        birth_year
# 14626        1834
# Youngest Players in dataset:
#        player_id name_first           name_last hand   birthdate country  \
# 54553     209519       Ivan              Savkin    U  20050210.0     USA
# 76992     221996   Isabella              Kruger    R  20050330.0     RSA
# 77254     222258      Linda         Fruhvirtova    R  20050501.0     CZE
# 77874     222878     Melisa               Ercan    U  20050901.0     TUR
# 77976     222980      Lucie          Havlickova    R  20050313.0     CZE
# 78116     223120     Briana               Szabo    U  20051126.0     ROU
# 78125     223129   Michaela                Laki    U  20050324.0     GRE
# 78132     223136     Rozhan          Karajayeva    U  20051009.0     TKM
# 78249     223253  Alexandra                Eala    U  20050523.0     PHL
# 78282     223286   Victoria  Jimenez Kasintseva    U  20050809.0     AND
#
#        gender  birth_year
# 54553    male        2005
# 76992  female        2005
# 77254  female        2005
# 77874  female        2005
# 77976  female        2005
# 78116  female        2005
# 78125  female        2005
# 78132  female        2005
# 78249  female        2005
# 78282  female        2005

# %% [markdown]
# ## Find tournament winner for a given year <a class="anchor" id="2-bullet"></a>

# %% [markdown]
# #### Who won the Barcelona Open in 2010? <a class="anchor" id="21-bullet"></a>

# %%
def find_tourney_winner(df_input, year, tourney_name_str, league='atp'):
    """ Find winner for a given year and tournament"""
    
    year_filter = (df_input['year'] == year)
    league_filter = (df_input['league'] == league)
    
    df = df_input[year_filter & league_filter]
    tournaments_matched = [t for t in df['tourney_name'].unique() if tourney_name_str.lower() in t.lower()]
    
    print(f'{len(tournaments_matched)} matching tourney(s) found in {year}: {tournaments_matched}')
    for tourney in tournaments_matched:
        name_filter = (df['tourney_name'] == tourney)
        df_filt = df[name_filter]
        df_finals = df_filt[df_filt['round'] == 'F']
        winner = df_finals['winner_name'].to_list()[0]
        print(f'{year} {tourney} winner: {winner}')

# %%
find_tourney_winner(df_matches, 2010, 'barc')
# Out:
# 1 matching tourney(s) found in 2010: ['Barcelona']
# 2010 Barcelona winner: Fernando Verdasco

# %% [markdown]
# ## Find titles and finals won by a player <a class="anchor" id="3-bullet"></a>

# %% [markdown]
# #### What silverware has Fernando Verdasco won? <a class="anchor" id="31-bullet"></a>
# The Barcelona Open winner we saw earlier

# %%
def find_player_titles(df_input, player_name_input, league='atp'):
    """ Find ATP silverware (finals and titles) won by a player """
    
    finals_filt = (df_input['round'] == 'F')
    league_filter = (df_input['league'] == league)
    df = df_input[finals_filt & league_filter]
    
    players_matched_won = [w for w in df['winner_name'].unique() if player_name_input.lower() in w.lower()]
    players_matched_lost = [w for w in df['loser_name'].unique() if player_name_input.lower() in w.lower()]
    players_matched = set(players_matched_won + players_matched_lost)
    
    result_cols = ['year', 'month', 'day', 'tourney_name', 'draw_size', 
                   'tourney_level', 'surface']
    
    if len(players_matched) == 0:
        print('No matching players found who have won or lost tourney finals')
    else:
        print(f'{len(players_matched)} matching player(s) found: {players_matched}')
        for player in players_matched:
            print(f'Player {player}')
            df_player_win = df[(df['winner_name'] == player)][result_cols + ['winner_seed']]
            df_player_win.rename(columns={'winner_seed': 'seed'}, inplace=True)
            df_player_win['result'] = 'Winner'
            
            df_player_finals = df[(df['loser_name'] == player)][result_cols + ['loser_seed']]
            df_player_finals['result'] = 'Finalist'
            df_player_finals.rename(columns={'loser_seed': 'seed'}, inplace=True)
            
            df_player = pd.concat([df_player_win, df_player_finals])
            
            with pd.option_context('display.max_rows', None):
                display(df_player.sort_values(by=['year', 'month', 'day']))

# %%
find_player_titles(df_matches, 'verdasco')
# Out:
# 1 matching player(s) found: {'Fernando Verdasco'}
# Player Fernando Verdasco
#         year  month  day         tourney_name draw_size tourney_level surface  \
# 134003  2004      3    1             Acapulco        32             A    Clay
# 133689  2004      4   12             Valencia        32             A    Clay
# 134856  2005      7   25            Kitzbuhel        48             A    Clay
# 143185  2007     10   22       St. Petersburg        32             A  Carpet
# 9731    2008      6   16           Nottingham        32             A   Grass
# 8720    2008      7   14                 Umag        28             A    Clay
# 10829   2009      1    4             Brisbane        32             A    Hard
# 10740   2009      8   23            New Haven        48             A    Hard
# 12784   2009      9   28         Kuala Lumpur        28             A    Hard
# 128601  2010      2    8             San Jose        32             A    Hard
# 129218  2010      4   11  Monte Carlo Masters        56             M    Clay
# 129273  2010      4   19            Barcelona        56             A    Clay
# 129541  2010      5   16                 Nice        28             A    Clay
# 138174  2011      2    7             San Jose        32             A    Hard
# 138926  2011      4   25              Estoril        28             A    Clay
# 139787  2011      7   25               Gstaad        28             A    Clay
# 147559  2012      2   27             Acapulco        32             A    Clay
# 145789  2013      7    8               Bastad        28             A    Clay
# 176115  2014      4    7              Houston        28             A    Clay
# 157469  2016      4   18            Bucharest        32             A    Clay
# 158158  2016      7   11               Bastad        32             A    Clay
# 160015  2017      2   27                Dubai        32             A    Hard
# 3413    2018      2   19       Rio de Janeiro        32             A    Clay
#
#        seed    result
# 134003  NaN  Finalist
# 133689  NaN    Winner
# 134856  NaN  Finalist
# 143185  6.0  Finalist
# 9731    3.0  Finalist
# 8720    1.0    Winner
# 10829   3.0  Finalist
# 10740   2.0    Winner
# 12784   2.0  Finalist
# 128601  2.0    Winner
# 129218  6.0  Finalist
# 129273  5.0    Winner
# 129541  2.0  Finalist
# 138174  1.0  Finalist
# 138926  2.0  Finalist
# 139787  4.0  Finalist
# 147559  8.0  Finalist
# 145789  8.0  Finalist
# 176115  4.0    Winner
# 157469  NaN    Winner
# 158158  5.0  Finalist
# 160015  NaN  Finalist
# 3413    8.0  Finalist

# %% [markdown]
# **As can be seen, it's been a few years since Verdasco has won some silverware. But he's fighting on the tour, blasting forehands whenever he can!**

# %% [markdown]
# ## Let's analyse some famous head-to-heads! <a class="anchor" id="4-bullet"></a>

# %%
def assign_GS_final(round, tourney_level):
    if (round=='F') & (tourney_level=='G'):
        return 'Yes'
    else:
        return 'No'
    

def player_h2h(df_input, player1, player2, league='atp', disp_results=True):
    """ Find head to head matches between player1 and player2 """
    
    league_filter = (df_input['league'] == league)
    df = df_input[league_filter]
    
    players = set(df['winner_name'].to_list() + df['loser_name'].to_list())
    player1_matched = [p for p in players if player1.lower() in p.lower()]
    if len(player1_matched) > 1:
        print(f'WARNING: multiple matched players found for {player1}: {player1_matched}')
        print(f'Considering only {player1_matched[0]}')
    p1 = player1_matched[0]
        
    player2_matched = [p for p in players if player2.lower() in p.lower()]
    if len(player2_matched) > 1:
        print(f'WARNING: multiple matched players found for {player2}: {player2_matched}')
        print(f'Considering only {player2_matched[0]}')
    p2 = player2_matched[0]
    
    result_cols = ['year', 'month', 'day', 'tourney_name', 'round', 'surface', 'score', 
                   'minutes', 'draw_size', 'tourney_level', 'winner_name', 'tourney_date']
    
    p1_w_p2_l = df[(df['winner_name']==p1) & (df['loser_name']==p2)][result_cols]
    p1_l_p2_w = df[(df['winner_name']==p2) & (df['loser_name']==p1)][result_cols]
    p1_w_p2_l.sort_values(by=['tourney_date'], inplace=True)
    p1_l_p2_w.sort_values(by=['tourney_date'], inplace=True)
    p1_w_p2_l.loc[:, 'win_no'] = np.linspace(1, len(p1_w_p2_l), num=len(p1_w_p2_l), endpoint=True)
    p1_l_p2_w.loc[:, 'win_no'] = np.linspace(1, len(p1_l_p2_w), num=len(p1_l_p2_w), endpoint=True)
    
    print(f'{p1}: {p2} H2H = {len(p1_w_p2_l)}:{len(p1_l_p2_w)}')

    if disp_results:
        print(f'{p1} defeats {p2} in {len(p1_w_p2_l)} matches')
        with pd.option_context('display.max_rows', None):
                display(p1_w_p2_l)
                
        print(f'{p2} defeats {p1} in {len(p1_l_p2_w)} matches')
        with pd.option_context('display.max_rows', None):
                display(p1_l_p2_w)
                
    combined = pd.concat([p1_w_p2_l, p1_l_p2_w])
    combined['GS_final'] = combined[['round', 'tourney_level']].apply(lambda x: assign_GS_final(*x), axis=1)
    return combined.sort_values(by=['tourney_date'])


def plot_h2h_over_time(h2h):
    """ Plot the h2h over time and surface, uses the output of the 'player_h2h' function """
    
    players = h2h['winner_name'].unique()
    p1, p2 = players[0], players[1]
    p1_sn, p2_sn = p1.split(' ')[1], p2.split(' ')[1]
    surfaces = h2h['surface'].unique()
    
    fig, ax = plt.subplots(figsize=(15,5))
    sns.lineplot(data=h2h, x='tourney_date', y='win_no', hue='winner_name', ax=ax)
    sns.scatterplot(data=h2h, x='tourney_date', y='win_no', hue='winner_name', size='GS_final', size_order=['Yes', 'No'], ax=ax)
    ax.set_xlabel('Match date')
    ax.set_ylabel('Win #')
    ax.set_title(f'Overall H2H {p1}:{p2}')
    ax.legend(fontsize='small')
    
    fig, axs = plt.subplots(nrows=1, ncols=len(surfaces), figsize=(15,4))
    for surface, ax in zip(surfaces, axs):
        h2h_surf = h2h[h2h['surface']==surface]
        
        h2h_surf_p1 = h2h_surf[h2h_surf['winner_name']==p1]
        h2h_surf_p1.loc[:, 'win_no_surf'] = np.linspace(1, len(h2h_surf_p1), num=len(h2h_surf_p1), endpoint=True)
        
        h2h_surf_p2 = h2h_surf[h2h_surf['winner_name']==p2]
        h2h_surf_p2.loc[:, 'win_no_surf'] = np.linspace(1, len(h2h_surf_p2), num=len(h2h_surf_p2), endpoint=True)
        combined = pd.concat([h2h_surf_p1, h2h_surf_p2])
        
        sns.lineplot(data=combined, x='tourney_date', y='win_no_surf', hue='winner_name', ax=ax)
        sns.scatterplot(data=combined, x='tourney_date', y='win_no_surf', hue='winner_name', size='GS_final', 
                        size_order=['Yes', 'No'], ax=ax)
        ax.set_xlabel('Match date')
        ax.set_ylabel('Win #')
        ax.set_title(f'H2H {p1_sn}:{p2_sn}\nOn {surface}')
        ax.tick_params(axis='x', labelrotation=45)
        ax.legend([],[], frameon=False)
    fig.tight_layout()

# %% [markdown]
# ## Federer v/s Nadal <a class="anchor" id="5-bullet"></a>
# The classic fire and ice h2h for the ages!

# %%
h2h = player_h2h(df_matches, 'federer', 'nadal')
# Out:
# Roger Federer: Rafael Nadal H2H = 17:24
# Roger Federer defeats Rafael Nadal in 17 matches
#         year  month  day          tourney_name round surface  \
# 135418  2005      3   21         Miami Masters     F    Hard
# 152275  2006      6   26             Wimbledon     F   Grass
# 152595  2006     11   13           Masters Cup    SF    Hard
# 141955  2007      5   14       Hamburg Masters     F    Clay
# 143027  2007      6   25             Wimbledon     F   Grass
# 143347  2007     11   12           Masters Cup    SF    Hard
# 10309   2009      5   10        Madrid Masters     F    Clay
# 131154  2010     11   21           Tour Finals     F    Hard
# 140721  2011     11   20           Tour Finals    RR    Hard
# 147715  2012      3    8  Indian Wells Masters    SF    Hard
# 168255  2015     10   26                 Basel     F    Hard
# 159570  2017      1   16       Australian Open     F    Hard
# 160124  2017      3    6  Indian Wells Masters   R16    Hard
# 160232  2017      3   20         Miami Masters     F    Hard
# 161981  2017     10    9      Shanghai Masters     F    Hard
# 612     2019      3    4  Indian Wells Masters    SF    Hard
# 1627    2019      7    1             Wimbledon    SF   Grass
#
#                             score  minutes draw_size tourney_level  \
# 135418  2-6 6-7(4) 7-6(5) 6-3 6-1    223.0        96             M
# 152275      6-0 7-6(5) 6-7(2) 6-3    178.0       128             G
# 152595                    6-4 7-5    113.0         8             F
# 141955                2-6 6-2 6-0    115.0        56             M
# 143027  7-6(7) 4-6 7-6(3) 2-6 6-2    225.0       128             G
# 143347                    6-4 6-1     59.0         8             F
# 10309                     6-4 6-4     86.0        56             M
# 131154                6-3 3-6 6-1     98.0         8             F
# 140721                    6-3 6-0     61.0        16             F
# 147715                    6-3 6-4     92.0        96             M
# 168255                6-3 5-7 6-3    123.0        32             A
# 159570        6-4 3-6 6-1 3-6 6-3    217.0       128             G
# 160124                    6-2 6-3     68.0       128             M
# 160232                    6-3 6-4     94.0       128             M
# 161981                    6-4 6-3     72.0        64             M
# 612                           W/O      NaN       128             M
# 1627           7-6(3) 1-6 6-3 6-4    182.0       128             G
#
#           winner_name tourney_date  win_no
# 135418  Roger Federer   2005-03-21     1.0
# 152275  Roger Federer   2006-06-26     2.0
# 152595  Roger Federer   2006-11-13     3.0
# 141955  Roger Federer   2007-05-14     4.0
# 143027  Roger Federer   2007-06-25     5.0
# 143347  Roger Federer   2007-11-12     6.0
# 10309   Roger Federer   2009-05-10     7.0
# 131154  Roger Federer   2010-11-21     8.0
# 140721  Roger Federer   2011-11-20     9.0
# 147715  Roger Federer   2012-03-08    10.0
# 168255  Roger Federer   2015-10-26    11.0
# 159570  Roger Federer   2017-01-16    12.0
# 160124  Roger Federer   2017-03-06    13.0
# 160232  Roger Federer   2017-03-20    14.0
# 161981  Roger Federer   2017-10-09    15.0
# 612     Roger Federer   2019-03-04    16.0
# 1627    Roger Federer   2019-07-01    17.0
# Rafael Nadal defeats Roger Federer in 24 matches
#         year  month  day          tourney_name round surface  \
# 132053  2004      3   22         Miami Masters   R32    Hard
# 136660  2005      5   23         Roland Garros    SF    Clay
# 151835  2006      2   27                 Dubai     F    Hard
# 151093  2006      4   17   Monte Carlo Masters     F    Clay
# 151219  2006      5    8          Rome Masters     F    Clay
# 152117  2006      5   29         Roland Garros     F    Clay
# 141900  2007      4   15   Monte Carlo Masters     F    Clay
# 142869  2007      5   28         Roland Garros     F    Clay
# 8215    2008      4   20   Monte Carlo Masters     F    Clay
# 8270    2008      5   11       Hamburg Masters     F    Clay
# 9157    2008      5   25         Roland Garros     F    Clay
# 9315    2008      6   23             Wimbledon     F   Grass
# 12757   2009      1   19       Australian Open     F    Hard
# 129491  2010      5    9        Madrid Masters     F    Clay
# 138675  2011      3   23         Miami Masters    SF    Hard
# 138979  2011      5    1        Madrid Masters    SF    Clay
# 139216  2011      5   22         Roland Garros     F    Clay
# 147142  2012      1   16       Australian Open    SF    Hard
# 144758  2013      3    7  Indian Wells Masters    QF    Hard
# 145314  2013      5   12          Rome Masters     F    Clay
# 146182  2013      8   11    Cincinnati Masters    QF    Hard
# 146868  2013     11    4           Tour Finals    SF    Hard
# 175300  2014      1   13       Australian Open    SF    Hard
# 1330    2019      5   27         Roland Garros    SF    Clay
#
#                                score  minutes draw_size tourney_level  \
# 132053                       6-3 6-3     70.0        96             M
# 136660               6-3 4-6 6-4 6-3    167.0       128             G
# 151835                   2-6 6-4 6-4    113.0        32             A
# 151093         6-2 6-7(2) 6-3 7-6(5)    230.0        64             M
# 151219  6-7(0) 7-6(5) 6-4 2-6 7-6(5)    305.0        64             M
# 152117            1-6 6-1 6-4 7-6(4)    182.0       128             G
# 141900                       6-4 6-4     95.0        56             M
# 142869               6-3 4-6 6-3 6-4    190.0       128             G
# 8215                         7-5 7-5    103.0        56             M
# 8270                  7-5 6-7(3) 6-3    172.0        56             M
# 9157                     6-1 6-3 6-0    108.0       128             G
# 9315       6-4 6-4 6-7(5) 6-7(8) 9-7    288.0       128             G
# 12757         7-5 3-6 7-6(3) 3-6 6-2    259.0       128             G
# 129491                    6-4 7-6(5)    131.0        56             M
# 138675                       6-3 6-2     79.0        96             M
# 138979                   5-7 6-1 6-3    156.0        56             M
# 139216            7-5 7-6(3) 5-7 6-1    220.0       128             G
# 147142         6-7(5) 6-2 7-6(5) 6-4    222.0       128             G
# 144758                       6-4 6-2     85.0        96             M
# 145314                       6-1 6-3     69.0        56             M
# 146182                   5-7 6-4 6-3    134.0        56             M
# 146868                       7-5 6-3     80.0         8             F
# 175300                7-6(4) 6-3 6-3    144.0       128             G
# 1330                     6-3 6-4 6-2    145.0       128             G
#
#          winner_name tourney_date  win_no
# 132053  Rafael Nadal   2004-03-22     1.0
# 136660  Rafael Nadal   2005-05-23     2.0
# 151835  Rafael Nadal   2006-02-27     3.0
# 151093  Rafael Nadal   2006-04-17     4.0
# 151219  Rafael Nadal   2006-05-08     5.0
# 152117  Rafael Nadal   2006-05-29     6.0
# 141900  Rafael Nadal   2007-04-15     7.0
# 142869  Rafael Nadal   2007-05-28     8.0
# 8215    Rafael Nadal   2008-04-20     9.0
# 8270    Rafael Nadal   2008-05-11    10.0
# 9157    Rafael Nadal   2008-05-25    11.0
# 9315    Rafael Nadal   2008-06-23    12.0
# 12757   Rafael Nadal   2009-01-19    13.0
# 129491  Rafael Nadal   2010-05-09    14.0
# 138675  Rafael Nadal   2011-03-23    15.0
# 138979  Rafael Nadal   2011-05-01    16.0
# 139216  Rafael Nadal   2011-05-22    17.0
# 147142  Rafael Nadal   2012-01-16    18.0
# 144758  Rafael Nadal   2013-03-07    19.0
# 145314  Rafael Nadal   2013-05-12    20.0
# 146182  Rafael Nadal   2013-08-11    21.0
# 146868  Rafael Nadal   2013-11-04    22.0
# 175300  Rafael Nadal   2014-01-13    23.0
# 1330    Rafael Nadal   2019-05-27    24.0

# %%
plot_h2h_over_time(h2h)

# %% [markdown]
# **The H2H is massively skewed by the highly disproportionate wins on Clay by Nadal. But since 2014, Federer clearly had the upper hand in their matches**

# %% [markdown]
# ## Djokovic v/s Nadal <a class="anchor" id="6-bullet"></a>
# The hottest baseline rivalry ever!

# %%
h2h = player_h2h(df_matches, 'novak djokovic', 'nadal')
# Out:
# Novak Djokovic: Rafael Nadal H2H = 29:27
# Novak Djokovic defeats Rafael Nadal in 29 matches
#         year  month  day          tourney_name round surface  \
# 141716  2007      3   19         Miami Masters    QF    Hard
# 142142  2007      8    5        Canada Masters    SF    Hard
# 8128    2008      3   13  Indian Wells Masters    SF    Hard
# 8496    2008      7   28    Cincinnati Masters    SF    Hard
# 11561   2009      8   16    Cincinnati Masters    SF    Hard
# 10902   2009     11    8         Paris Masters    SF    Hard
# 12798   2009     11   22           Tour Finals    RR    Hard
# 138582  2011      3   10  Indian Wells Masters     F    Hard
# 138677  2011      3   23         Miami Masters     F    Hard
# 138981  2011      5    1        Madrid Masters     F    Clay
# 139036  2011      5    8          Rome Masters     F    Clay
# 139491  2011      6   20             Wimbledon     F   Grass
# 140199  2011      8   29               US Open     F    Hard
# 147143  2012      1   16       Australian Open     F    Hard
# 145076  2013      4   14   Monte Carlo Masters     F    Clay
# 146574  2013      9   30               Beijing     F    Hard
# 146869  2013     11    4           Tour Finals     F    Hard
# 175962  2014      3   19         Miami Masters     F    Hard
# 176412  2014      5   11          Rome Masters     F    Clay
# 166446  2015      4   12   Monte Carlo Masters    SF    Clay
# 166888  2015      5   24         Roland Garros    QF    Clay
# 168053  2015     10    5               Beijing     F    Hard
# 168347  2015     11   15           Tour Finals    SF    Hard
# 156448  2016      1    4                  Doha     F    Hard
# 157190  2016      3    7  Indian Wells Masters    SF    Hard
# 157657  2016      5    9          Rome Masters    QF    Clay
# 4619    2018      7    2             Wimbledon    SF   Grass
# 139     2019      1   14       Australian Open     F    Hard
# 5670    2020      1    6               Atp Cup     F    Hard
#
#                           score  minutes draw_size tourney_level  \
# 141716                  6-3 6-4     97.0        96             M
# 142142                  7-5 6-3    111.0        56             M
# 8128                    6-3 6-2     88.0        96             M
# 8496                    6-1 7-5     86.0        56             M
# 11561                   6-1 6-4     92.0        56             M
# 10902                   6-2 6-3     77.0        48             M
# 12798                7-6(5) 6-3    118.0         8             F
# 138582              4-6 6-3 6-2    146.0        96             M
# 138677           4-6 6-3 7-6(4)    202.0        96             M
# 138981                  7-5 6-4    138.0        56             M
# 139036                  6-4 6-4    133.0        56             M
# 139491          6-4 6-1 1-6 6-3    148.0       128             G
# 140199       6-2 6-4 6-7(3) 6-1    250.0       128             G
# 147143   5-7 6-4 6-2 6-7(5) 7-5    353.0       128             G
# 145076               6-2 7-6(1)    112.0        56             M
# 146574                  6-3 6-4     87.0        32             A
# 146869                  6-3 6-4     96.0         8             F
# 175962                  6-3 6-3     84.0        96             M
# 176412              4-6 6-3 6-3    139.0        56             M
# 166446                  6-3 6-3     98.0        56             M
# 166888              7-5 6-3 6-1    146.0       128             G
# 168053                  6-2 6-2     91.0        32             A
# 168347                  6-3 6-3      NaN         8             F
# 156448                  6-1 6-2     73.0        32             A
# 157190               7-6(5) 6-2    118.0       128             M
# 157657               7-5 7-6(4)    144.0        64             M
# 4619    6-4 3-6 7-6(9) 3-6 10-8    315.0       128             G
# 139                 6-3 6-2 6-3    124.0       128             G
# 5670                 6-2 7-6(4)    115.0        24             A
#
#            winner_name tourney_date  win_no
# 141716  Novak Djokovic   2007-03-19     1.0
# 142142  Novak Djokovic   2007-08-05     2.0
# 8128    Novak Djokovic   2008-03-13     3.0
# 8496    Novak Djokovic   2008-07-28     4.0
# 11561   Novak Djokovic   2009-08-16     5.0
# 10902   Novak Djokovic   2009-11-08     6.0
# 12798   Novak Djokovic   2009-11-22     7.0
# 138582  Novak Djokovic   2011-03-10     8.0
# 138677  Novak Djokovic   2011-03-23     9.0
# 138981  Novak Djokovic   2011-05-01    10.0
# 139036  Novak Djokovic   2011-05-08    11.0
# 139491  Novak Djokovic   2011-06-20    12.0
# 140199  Novak Djokovic   2011-08-29    13.0
# 147143  Novak Djokovic   2012-01-16    14.0
# 145076  Novak Djokovic   2013-04-14    15.0
# 146574  Novak Djokovic   2013-09-30    16.0
# 146869  Novak Djokovic   2013-11-04    17.0
# 175962  Novak Djokovic   2014-03-19    18.0
# 176412  Novak Djokovic   2014-05-11    19.0
# 166446  Novak Djokovic   2015-04-12    20.0
# 166888  Novak Djokovic   2015-05-24    21.0
# 168053  Novak Djokovic   2015-10-05    22.0
# 168347  Novak Djokovic   2015-11-15    23.0
# 156448  Novak Djokovic   2016-01-04    24.0
# 157190  Novak Djokovic   2016-03-07    25.0
# 157657  Novak Djokovic   2016-05-09    26.0
# 4619    Novak Djokovic   2018-07-02    27.0
# 139     Novak Djokovic   2019-01-14    28.0
# 5670    Novak Djokovic   2020-01-06    29.0
# Rafael Nadal defeats Novak Djokovic in 27 matches
#         year  month  day                 tourney_name round surface  \
# 152114  2006      5   29                Roland Garros    QF    Clay
# 141814  2007      3    5         Indian Wells Masters     F    Hard
# 142007  2007      5    7                 Rome Masters    QF    Clay
# 142868  2007      5   28                Roland Garros    SF    Clay
# 143026  2007      6   25                    Wimbledon    SF   Grass
# 143346  2007     11   12                  Masters Cup    RR    Hard
# 8269    2008      5   11              Hamburg Masters    SF    Clay
# 9156    2008      5   25                Roland Garros    SF    Clay
# 7384    2008      6    9                 Queen's Club     F   Grass
# 9913    2008      8   11             Beijing Olympics    SF    Hard
# 13031   2009      3    6  Davis Cup WG R1: ESP vs SRB    RR    Clay
# 11272   2009      4   12          Monte Carlo Masters     F    Clay
# 11374   2009      4   27                 Rome Masters     F    Clay
# 10307   2009      5   10               Madrid Masters    SF    Clay
# 130605  2010      8   30                      US Open     F    Hard
# 131160  2010     11   21                  Tour Finals    RR    Hard
# 148033  2012      4   15          Monte Carlo Masters     F    Clay
# 148306  2012      5   13                 Rome Masters     F    Clay
# 148487  2012      5   27                Roland Garros     F    Clay
# 145493  2013      5   27                Roland Garros    SF    Clay
# 146129  2013      8    5               Canada Masters    SF    Hard
# 146360  2013      8   26                      US Open     F    Hard
# 176593  2014      5   26                Roland Garros     F    Clay
# 160618  2017      5    8               Madrid Masters    SF    Clay
# 4141    2018      5   14                 Rome Masters    SF    Clay
# 1096    2019      5   13                 Rome Masters     F    Clay
# 6728    2020      9   28                Roland Garros     F    Clay
#
#                          score  minutes draw_size tourney_level   winner_name  \
# 152114             6-4 6-4 RET    114.0       128             G  Rafael Nadal
# 141814                 6-2 7-5     94.0        96             M  Rafael Nadal
# 142007                 6-2 6-3    101.0        56             M  Rafael Nadal
# 142868             7-5 6-4 6-2    148.0       128             G  Rafael Nadal
# 143026         3-6 6-1 4-1 RET    101.0       128             G  Rafael Nadal
# 143346                 6-4 6-4    104.0         8             F  Rafael Nadal
# 8269               7-5 2-6 6-2    183.0        56             M  Rafael Nadal
# 9156            6-4 6-2 7-6(3)    169.0       128             G  Rafael Nadal
# 7384                7-6(6) 7-5    136.0        56             A  Rafael Nadal
# 9913               6-4 1-6 6-4    131.0        64             A  Rafael Nadal
# 13031              6-4 6-4 6-1      NaN         4             D  Rafael Nadal
# 11272              6-3 2-6 6-1    163.0        56             M  Rafael Nadal
# 11374               7-6(2) 6-2    123.0        56             M  Rafael Nadal
# 10307        3-6 7-6(5) 7-6(9)    243.0        56             M  Rafael Nadal
# 130605         6-4 5-7 6-4 6-2    223.0       128             G  Rafael Nadal
# 131160                 7-5 6-2    112.0         8             F  Rafael Nadal
# 148033                 6-3 6-1     79.0        56             M  Rafael Nadal
# 148306                 7-5 6-3    141.0        56             M  Rafael Nadal
# 148487         6-4 6-3 2-6 7-5    229.0       128             G  Rafael Nadal
# 145493  6-4 3-6 6-1 6-7(3) 9-7    277.0       128             G  Rafael Nadal
# 146129          6-4 3-6 7-6(2)    149.0        56             M  Rafael Nadal
# 146360         6-2 3-6 6-4 6-1    201.0       128             G  Rafael Nadal
# 176593         3-6 7-5 6-2 6-4    211.0       128             G  Rafael Nadal
# 160618                 6-2 6-4     98.0        64             M  Rafael Nadal
# 4141                7-6(4) 6-3    116.0        64             M  Rafael Nadal
# 1096               6-0 4-6 6-1    145.0        64             M  Rafael Nadal
# 6728               6-0 6-2 7-5    161.0       128             G  Rafael Nadal
#
#        tourney_date  win_no
# 152114   2006-05-29     1.0
# 141814   2007-03-05     2.0
# 142007   2007-05-07     3.0
# 142868   2007-05-28     4.0
# 143026   2007-06-25     5.0
# 143346   2007-11-12     6.0
# 8269     2008-05-11     7.0
# 9156     2008-05-25     8.0
# 7384     2008-06-09     9.0
# 9913     2008-08-11    10.0
# 13031    2009-03-06    11.0
# 11272    2009-04-12    12.0
# 11374    2009-04-27    13.0
# 10307    2009-05-10    14.0
# 130605   2010-08-30    15.0
# 131160   2010-11-21    16.0
# 148033   2012-04-15    17.0
# 148306   2012-05-13    18.0
# 148487   2012-05-27    19.0
# 145493   2013-05-27    20.0
# 146129   2013-08-05    21.0
# 146360   2013-08-26    22.0
# 176593   2014-05-26    23.0
# 160618   2017-05-08    24.0
# 4141     2018-05-14    25.0
# 1096     2019-05-13    26.0
# 6728     2020-09-28    27.0

# %%
plot_h2h_over_time(h2h)

# %% [markdown]
# **A rivalry that has given us more highlight reel moments than any other matchup! They each have their surfaces where they dominate the other, but Djokovic leads their H2H very slightly**

# %% [markdown]
# ## Sampras v/s Agassi <a class="anchor" id="7-bullet"></a>
# The contrasting style battle of the 90s!

# %%
h2h = player_h2h(df_matches, 'sampras', 'agassi')
# Out:
# Pete Sampras: Andre Agassi H2H = 20:14
# Pete Sampras defeats Andre Agassi in 20 matches
#         year  month  day          tourney_name round surface  \
# 73817   1990      2   19          Philadelphia   R16  Carpet
# 76215   1990      8   27               US Open     F    Hard
# 80643   1991     11   12           Tour Finals    RR  Carpet
# 49936   1993      6   21             Wimbledon    QF   Grass
# 22306   1994      3    7         Miami Masters     F    Hard
# 22528   1994      3   28                 Osaka    SF    Hard
# 25353   1994     11   15           Tour Finals    SF  Carpet
# 18427   1995      3    6  Indian Wells Masters     F    Hard
# 20633   1995      8   28               US Open     F    Hard
# 29945   1996      2   12              San Jose     F    Hard
# 33013   1996     10   21     Stuttgart Masters    QF  Carpet
# 33174   1996     11   19           Tour Finals    RR  Carpet
# 125725  1998      4   20   Monte Carlo Masters   R32    Clay
# 115701  1999      6   21             Wimbledon     F   Grass
# 115990  1999      7   26           Los Angeles     F    Hard
# 116160  1999      8    9    Cincinnati Masters    SF    Hard
# 117089  1999     11   22           Tour Finals     F    Hard
# 170890  2001      8   27               US Open    QF    Hard
# 155869  2002      4   22               Houston    SF    Clay
# 155614  2002      8   26               US Open     F    Hard
#
#                               score  minutes draw_size tourney_level  \
# 73817                   5-7 7-5 RET      NaN        48             A
# 76215                   6-4 6-3 6-2      NaN       128             G
# 80643                   6-3 1-6 6-3     97.0         8             F
# 49936           6-2 6-2 3-6 3-6 6-4      NaN       128             G
# 22306                   5-7 6-3 6-3    135.0        96             M
# 22528                       6-3 6-1     55.0        32             A
# 25353                4-6 7-6(5) 6-3    170.0         8             F
# 18427                   7-5 6-3 7-5    133.0        56             M
# 20633               6-4 6-3 4-6 7-5      NaN       128             G
# 29945                       6-2 6-3     67.0        32             A
# 33013                       6-4 6-1     61.0        48             M
# 33174                       6-2 6-1     51.0         9             F
# 125725                      6-4 7-5     80.0        56             M
# 115701                  6-3 6-4 7-5    115.0       128             G
# 115990                7-6(3) 7-6(1)     95.0        32             A
# 116160                   7-6(7) 6-4     82.0        56             M
# 117089                  6-1 7-5 6-4    105.0         8             F
# 170890  6-7(7) 7-6(2) 7-6(2) 7-6(5)    212.0       128             G
# 155869                      6-1 7-5     80.0        32             A
# 155614              6-3 6-4 5-7 6-4    172.0       128             G
#
#          winner_name tourney_date  win_no
# 73817   Pete Sampras   1990-02-19     1.0
# 76215   Pete Sampras   1990-08-27     2.0
# 80643   Pete Sampras   1991-11-12     3.0
# 49936   Pete Sampras   1993-06-21     4.0
# 22306   Pete Sampras   1994-03-07     5.0
# 22528   Pete Sampras   1994-03-28     6.0
# 25353   Pete Sampras   1994-11-15     7.0
# 18427   Pete Sampras   1995-03-06     8.0
# 20633   Pete Sampras   1995-08-28     9.0
# 29945   Pete Sampras   1996-02-12    10.0
# 33013   Pete Sampras   1996-10-21    11.0
# 33174   Pete Sampras   1996-11-19    12.0
# 125725  Pete Sampras   1998-04-20    13.0
# 115701  Pete Sampras   1999-06-21    14.0
# 115990  Pete Sampras   1999-07-26    15.0
# 116160  Pete Sampras   1999-08-09    16.0
# 117089  Pete Sampras   1999-11-22    17.0
# 170890  Pete Sampras   2001-08-27    18.0
# 155869  Pete Sampras   2002-04-22    19.0
# 155614  Pete Sampras   2002-08-26    20.0
# Andre Agassi defeats Pete Sampras in 14 matches
#         year  month  day          tourney_name round surface  \
# 97836   1989      5   15                  Rome   R32    Clay
# 76917   1990     11   12           Tour Finals    RR  Carpet
# 67558   1992      4   27               Atlanta     F    Clay
# 68008   1992      5   25         Roland Garros    QF    Clay
# 25243   1994     10   31         Paris Masters    QF  Carpet
# 17920   1995      1   16       Australian Open     F    Hard
# 18522   1995      3   13         Miami Masters     F    Hard
# 20139   1995      7   24        Canada Masters     F    Hard
# 124925  1998      2    9              San Jose     F    Hard
# 127028  1998      8    3        Canada Masters    QF    Hard
# 117086  1999     11   22           Tour Finals    RR    Hard
# 174356  2000      1   17       Australian Open    SF    Hard
# 169350  2001      3   12  Indian Wells Masters     F    Hard
# 169899  2001      7   23           Los Angeles     F    Hard
#
#                             score  minutes draw_size tourney_level  \
# 97836                     6-2 6-1      NaN        64             M
# 76917                     6-4 6-2      NaN         8             F
# 67558                     7-5 6-4     73.0        32             A
# 68008              7-6(6) 6-2 6-1    120.0       128             G
# 25243                  7-6(6) 7-5    121.0        48             M
# 17920          4-6 6-1 7-6(6) 6-4      NaN       128             G
# 18522              3-6 6-2 7-6(3)    133.0        96             M
# 20139                 3-6 6-2 6-3    113.0        56             M
# 124925                    6-2 6-4     69.0        32             A
# 127028             6-7(5) 6-1 6-2    121.0        56             M
# 117086                    6-2 6-2     59.0         8             F
# 174356  6-4 3-6 6-7(0) 7-6(5) 6-1    175.0       128             G
# 169350             7-6(5) 7-5 6-1    131.0        64             M
# 169899                    6-4 6-2     90.0        32             A
#
#          winner_name tourney_date  win_no
# 97836   Andre Agassi   1989-05-15     1.0
# 76917   Andre Agassi   1990-11-12     2.0
# 67558   Andre Agassi   1992-04-27     3.0
# 68008   Andre Agassi   1992-05-25     4.0
# 25243   Andre Agassi   1994-10-31     5.0
# 17920   Andre Agassi   1995-01-16     6.0
# 18522   Andre Agassi   1995-03-13     7.0
# 20139   Andre Agassi   1995-07-24     8.0
# 124925  Andre Agassi   1998-02-09     9.0
# 127028  Andre Agassi   1998-08-03    10.0
# 117086  Andre Agassi   1999-11-22    11.0
# 174356  Andre Agassi   2000-01-17    12.0
# 169350  Andre Agassi   2001-03-12    13.0
# 169899  Andre Agassi   2001-07-23    14.0

# %%
plot_h2h_over_time(h2h)

# %% [markdown]
# **Another classic rivalry, a matchup of two very contrasting styles. Sampras had the lead in this H2H for most of their careers and the gap only kept widening**

# %% [markdown]
# ## Let's track player's rank through the years! <a class="anchor" id="8-bullet"></a>

# %%
def track_player_rank(df_input, players, league='atp', plot_ylim=100):
    """ Visually track one or more player's rank through their playing years """
    
    league_filter = (df_input['league'] == league)
    df = df_input[league_filter]
    
    fig, ax = plt.subplots(figsize=(15,5))
    ax.set_xlabel('Date')
    ax.set_ylabel('Rank')
    ax.set_title('Player rank')
    ax.set_ylim([0, plot_ylim])
    
    all_players = set(df['winner_name'].to_list() + df['loser_name'].to_list())
    matched_players = []
    for player in players:
        player_matched = [p for p in all_players if player.lower() in p.lower()]
        if len(player_matched) == 0:
            print(f'WARNING: no matched players found for {player}')
            continue
        if len(player_matched) > 1:
            print(f'WARNING: multiple matched players found for {player}: {player_matched}')
            print(f'Considering only {player_matched[0]}')
        p = player_matched[0]
        matched_players.append(p)
            
    df_player_win = df[df['winner_name'].isin(matched_players)][['tourney_date', 'winner_rank', 'winner_name']]
    df_player_win.rename(columns={'winner_rank': 'rank', 'winner_name': 'name'}, inplace=True)
    df_player_loss = df[df['loser_name'].isin(matched_players)][['tourney_date', 'loser_rank', 'loser_name']]
    df_player_loss.rename(columns={'loser_rank': 'rank', 'loser_name': 'name'}, inplace=True)
    df_player = pd.concat([df_player_win, df_player_loss])
    df_player.sort_values(by=['tourney_date'], inplace=True, ignore_index=True)
    sns.lineplot(data=df_player, x='tourney_date', y='rank', hue='name', ax=ax)
    ax.legend(fontsize='medium')
    ax.set_ylabel('Rank')

# %% [markdown]
# ### The big 3! <a class="anchor" id="81-bullet"></a>

# %%
track_player_rank(df_matches, ['federer', 'nadal', 'novak djokovic'], plot_ylim=30)

# %% [markdown]
# **The big 3 clearly have had a chokehold on the top ranks in the sport since 2008, showcasing their utter dominance**

# %% [markdown]
# ### The superstars of the 90s! <a class="anchor" id="82-bullet"></a>

# %%
track_player_rank(df_matches, ['sampras', 'agassi', 'boris becker'], plot_ylim=30)

# %% [markdown]
# **Of the 3 tennis stars of the 90's, it seems Agassi was the most temperamental with wide swings in his ranking. Sampras was the most consistent and was #1 for most of the 90s**

# %% [markdown]
# ## Which major tournaments are the most and least upset prone? <a class="anchor" id="9-bullet"></a>
#
# Let's define an upset prone tournament as one in which more players outside the top seeds make it to a late stage such as the QF's. Conversely, a less upset prone one is one in which the top seeds make it to the late stage, as expected by the seeding. For ease, let's consider only the Grand Slams and the Master's 1000 tournaments

# %%
def convert_seed_to_int(seeds):
    """ Convert list of seed str's to int """
    
    seeds = set(seeds)
    seeds_conv = []
    
    for seed in seeds:
        try:
            seeds_conv.append(int(float(seed)))
        except:
            seeds_conv.append(0)
    return set(seeds_conv)


def tourney_upset_fraction(df_input, tourney_name, year_start=2000, year_end=2023, stage='QF', top_n=10):
    """ Calculate the 'upset fraction' of a tournament over a specified set of years (by default, since 2000).
    The upset fraction is defined as the fraction of players in the specified stage (can be 'QF', 'SF' or 'F', 
    by default the 'QF') who are outside the top-n seeds, where n is an input to the function (by default 10)"""
    
    tourney_filter = (df_input['tourney_name']==tourney_name)
    t_start = pd.to_datetime(f'{year_start}-01-01', format='%Y-%m-%d')
    t_end = pd.to_datetime(f'{year_end}-01-01', format='%Y-%m-%d')
    year_filter = (df_input['tourney_date'] > t_start) & (df_input['tourney_date'] < t_end)
    round_filter = (df_input['round'] == stage)
    
    df = df_input[tourney_filter & year_filter & round_filter]
    
    years = df['year'].unique()
    results = {
        'year': [],
        'upset_frac': []
    }
    for year in years:
        results['year'].append(year)
        df_yr = df[df['year']==year]
        player_seeds = convert_seed_to_int(df_yr['winner_seed'].to_list() + df_yr['loser_seed'].to_list())
        n_top_seeds = set(list(np.linspace(1, top_n, top_n, dtype=int)))
        player_seeds_in_top_n = player_seeds.intersection(n_top_seeds)
        
        upset_frac = 1 - len(player_seeds_in_top_n)/top_n
        results['upset_frac'].append(upset_frac)
        
    return pd.DataFrame(results)

# %% [markdown]
# ### Grand Slams <a class="anchor" id="91-bullet"></a>

# %%
# make consistent the US Open tournament name across rows
df_matches.loc[df_matches['tourney_name']=='Us Open',['tourney_name']] = 'US Open'

# %%
fig, ax = plt.subplots(figsize=(15,5))

gs_tourneys = df_matches[df_matches['tourney_level']=='G']['tourney_name'].unique()
for i, tourney in enumerate(gs_tourneys):
    df_tourney = tourney_upset_fraction(df_matches, tourney)
    df_tourney['tourney'] = tourney
    sns.lineplot(data=df_tourney, x='year', y='upset_frac', label=tourney, ax=ax)

ax.legend(fontsize='x-small')

# %% [markdown]
# **As can be expected by it's relatively late in the year calendar slot by which time many top players come down with fatigue or injuries from the early parts of the season, the US Open tends to be the more upset prone slam of late**

# %% [markdown]
# ### Masters 1000's <a class="anchor" id="92-bullet"></a>

# %%
# make consistent the Masters 1000 tournament names across rows
df_matches.loc[df_matches['tourney_name']=='Indian Wells',['tourney_name']] = 'Indian Wells Masters'
df_matches.loc[df_matches['tourney_name']=='Rome',['tourney_name']] = 'Rome Masters'
df_matches.loc[df_matches['tourney_name']=='Cincinnati',['tourney_name']] = 'Cincinnati Masters'
df_matches.loc[df_matches['tourney_name']=='Toronto',['tourney_name']] = 'Canada Masters'

# %%
fig, ax = plt.subplots(nrows=2, ncols=1, figsize=(15,10))

gs_tourneys = df_matches[df_matches['tourney_level']=='M']['tourney_name'].unique()
for i, tourney in enumerate(gs_tourneys):
    df_tourney = tourney_upset_fraction(df_matches, tourney, year_start=2005)
    df_tourney['tourney'] = tourney
    if i<=5:
        sns.lineplot(data=df_tourney, x='year', y='upset_frac', label=tourney, ax=ax[0])
    else:
        sns.lineplot(data=df_tourney, x='year', y='upset_frac', label=tourney, ax=ax[1])

ax[0].legend(fontsize='x-small')
ax[1].legend(fontsize='x-small')

# %% [markdown]
# **As has been known, Rome is the least upset prone tourney among the Clay masters, owing to its proximity to Roland Garros in the calendar and its very similar playing conditions. Rome is known to attract the top players who look to get in match-shape for RG. Madrid due to its altitude and faster playing conditions is atypical for a Clay tourney and tends to see more upsets.**
#
# **Note that Delray Beach is not a Masters but an ATP 250 event!**
#
# **Among the hard court masters, Cincinnati seems to be the least upset prone**

# %% [markdown]
# ## Tennis Player Analysis <a class="anchor" id="10-bullet"></a>
#
# We'll use the tennis players dataset and enhance it using the matches dataset. For this exercise, lets consider Male players born after 1950. For the plots, consider further only players to have won at least one title and those that have been in the top 10 at least once in their career

# %%
# This is what the players dataset looks like
df_players_cleaned.head()
# Out:
#    player_id      name_first name_last hand   birthdate country gender  \
# 0     100001         Gardnar    Mulloy    R  19131122.0     USA   male
# 1     100002          Pancho    Segura    R  19210620.0     ECU   male
# 2     100003           Frank   Sedgman    R  19271002.0     AUS   male
# 3     100004        Giuseppe     Merlo    R  19271011.0     ITA   male
# 4     100005  Richard Pancho  Gonzales    R  19280509.0     USA   male
#
#    birth_year league
# 0        1913    atp
# 1        1921    atp
# 2        1927    atp
# 3        1927    atp
# 4        1928    atp

# %%
df_players_male_new = df_players_cleaned[(df_players_cleaned['birth_year']>=1950) & (df_players_cleaned['gender']=='male')]

# %%
# correcting Stan Wawrinka's name
df_players_male_new.at[4525, 'name_first'] = 'Stan'

# Create a composite full name column
df_players_male_new['name'] = df_players_male_new['name_first'] + ' ' + df_players_male_new['name_last']

df_players_male_new.head()
# Out:
#      player_id name_first  name_last hand   birthdate country gender  \
# 197     100198     Alvaro   Betancur    R  19500103.0     COL   male
# 198     100199    Patrice  Dominguez    L  19500112.0     FRA   male
# 199     100200    Antonio  Zugarelli    R  19500117.0     ITA   male
# 200     100201        Syd       Ball    R  19500124.0     AUS   male
# 201     100202     George      Amaya    L  19500212.0     USA   male
#
#      birth_year league               name
# 197        1950    atp    Alvaro Betancur
# 198        1950    atp  Patrice Dominguez
# 199        1950    atp  Antonio Zugarelli
# 200        1950    atp           Syd Ball
# 201        1950    atp       George Amaya

# %%
# a filtered subset of the matches dataset with male players matches only 
df_matches_male = df_matches[df_matches['league']=='atp']

print(f'No. of ATP matches in dataset: {len(df_matches_male)}')
# Out:
# No. of ATP matches in dataset: 177938

# %% [markdown]
# ### Tennis Player Feature engineering! <a class="anchor" id="1005-bullet"></a>
#
# Create some features for each player in the dataset using the matches dataset. These features will be used to generate the plots in the tennis player analysis:
# - player grass, clay, hard and carpet court wins, losses and win %
# - player finals played and titles won, including Grand Slams
# - No. of top 10 wins by a player (no. of matches where a player has defeated an opponent ranked in the top 10)

# %%
winners = df_matches_male['winner_name'].to_numpy()
rounds = df_matches_male['round'].to_numpy()
losers = df_matches_male['loser_name'].to_numpy()
tourney_level = df_matches_male['tourney_level'].to_numpy()
winner_rank = df_matches_male['winner_rank'].to_numpy()
loser_rank = df_matches_male['loser_rank'].to_numpy()

finals = (rounds == 'F')
gs = (tourney_level == 'G')

def player_total_wins(player_name, winners=winners):
    return sum(winners == player_name)

def find_player_ntitles(player_name, winners=winners, finals=finals):
    player_filt = (winners == player_name)
    return sum(finals & player_filt)

def player_total_matches(player_name, winners=winners, losers=losers):
    wins_filt = (winners == player_name)
    losses_filt = (losers == player_name)
    return sum(wins_filt | losses_filt)

def find_player_ntitles_GS(player_name, winners=winners, gs=gs, finals=finals):
    player_filt = (winners == player_name)
    return sum(finals & player_filt & gs)

# %%
def find_best_rank(player_name, winners=winners, winner_rank=winner_rank, losers=losers, loser_rank=loser_rank):
    import numpy as np
    try:
        wins_filt = (winners == player_name)
        wins_rank = winner_rank[wins_filt]
        best_wins_rank = np.min(wins_rank[~np.isnan(wins_rank)])
        losses_filt = (losers == player_name)
        loss_rank = loser_rank[losses_filt]
        best_loss_rank = np.min(loss_rank[~np.isnan(loss_rank)])
        return np.min(np.array([best_wins_rank, best_loss_rank]))
    except:
        return 0

# %%
def find_player_nfinals(player_name, losers=losers, finals=finals):
    losses_filt = (losers == player_name)
    return sum(finals & losses_filt)

def find_player_nfinals_gs(player_name, losers=losers, finals=finals, gs=gs):
    losses_filt = (losers == player_name)
    return sum(finals & losses_filt & gs)

def find_player_ntop10wins(player_name, winners=winners, loser_rank=loser_rank):
    player_filt = (winners == player_name)
    top10_filt = (loser_rank <= 10)
    return sum(player_filt & top10_filt)

# %%
df_matches_male['surface'].unique()
# Out:
# array(['Hard', 'Clay', 'Grass', 'Carpet', nan], dtype=object)

# %%
surface = df_matches_male['surface'].to_numpy()

def player_hard_wins(player_name, winners=winners, surface=surface):
    hard_filt = (surface == 'Hard')
    win_filt = (winners == player_name)
    return sum(hard_filt & win_filt)

def player_hard_losses(player_name, losers=losers, surface=surface):
    hard_filt = (surface == 'Hard')
    loss_filt = (losers == player_name)
    return sum(hard_filt & loss_filt)

def player_clay_wins(player_name, winners=winners, surface=surface):
    clay_filt = (surface == 'Clay')
    win_filt = (winners == player_name)
    return sum(clay_filt & win_filt)

def player_clay_losses(player_name, losers=losers, surface=surface):
    clay_filt = (surface == 'Clay')
    loss_filt = (losers == player_name)
    return sum(clay_filt & loss_filt)

def player_grass_wins(player_name, winners=winners, surface=surface):
    grass_filt = (surface == 'Grass')
    win_filt = (winners == player_name)
    return sum(grass_filt & win_filt)

def player_grass_losses(player_name, losers=losers, surface=surface):
    grass_filt = (surface == 'Grass')
    loss_filt = (losers == player_name)
    return sum(grass_filt & loss_filt)

def player_carpet_wins(player_name, winners=winners, surface=surface):
    carpet_filt = (surface == 'Carpet')
    win_filt = (winners == player_name)
    return sum(carpet_filt & win_filt)

def player_carpet_losses(player_name, losers=losers, surface=surface):
    carpet_filt = (surface == 'Carpet')
    loss_filt = (losers == player_name)
    return sum(carpet_filt & loss_filt)

# %% [markdown]
# #### Pandarellel
#
# This is a very useful python library that uses all the cores available in your local machine for pandas applications on large dataframes, such as for example applying a function on a column. It also displays a useful progress bar for each of the cores showing the progress of the operation.
#
# We shall use this for applying the feature engineering functions defined earlier on the large players dataset. These functions are applied on each player across all matches in the matches dataframe, hence are ideal for parallelisation using pandarellel

# %%
from pandarallel import pandarallel
pandarallel.initialize(progress_bar=True)
# Out:
# INFO: Pandarallel will run on 6 workers.
# INFO: Pandarallel will use standard multiprocessing data transfer (pipe) to transfer data between the main process and workers.
#
# WARNING: You are on Windows. If you detect any issue with pandarallel, be sure you checked out the Troubleshooting page:
# https://nalepae.github.io/pandarallel/troubleshooting/

# %%
df_players_male_new['n_titles'] = df_players_male_new['name'].parallel_apply(find_player_ntitles)
# Out:
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=6970), Label(value='0 / 6970'))), …

# %%
df_players_male_new['n_matches'] = df_players_male_new['name'].parallel_apply(player_total_matches)
# Out:
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=6970), Label(value='0 / 6970'))), …

# %%
df_players_male_new['n_wins'] = df_players_male_new['name'].parallel_apply(player_total_wins)
# Out:
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=6970), Label(value='0 / 6970'))), …

# %%
df_players_male_new['n_titles_gs'] = df_players_male_new['name'].parallel_apply(find_player_ntitles_GS)
# Out:
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=6970), Label(value='0 / 6970'))), …

# %%
df_players_male_new['best_rank'] = df_players_male_new['name'].parallel_apply(find_best_rank)
# Out:
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=6970), Label(value='0 / 6970'))), …

# %%
df_players_male_new['n_finals'] = df_players_male_new['name'].parallel_apply(find_player_nfinals)
# Out:
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=6970), Label(value='0 / 6970'))), …

# %%
df_players_male_new['n_finals_gs'] = df_players_male_new['name'].parallel_apply(find_player_nfinals_gs)
# Out:
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=6970), Label(value='0 / 6970'))), …

# %%
df_players_male_new['n_top10_wins'] = df_players_male_new['name'].parallel_apply(find_player_ntop10wins)
# Out:
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=6970), Label(value='0 / 6970'))), …

# %%
df_players_male_new['win_perc'] = 100*df_players_male_new['n_wins']/df_players_male_new['n_matches']

# %%
df_players_male_new['n_wins_hard'] = df_players_male_new['name'].parallel_apply(player_hard_wins)
# Out:
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=6970), Label(value='0 / 6970'))), …

# %%
df_players_male_new['n_loss_hard'] = df_players_male_new['name'].parallel_apply(player_hard_losses)
# Out:
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=6970), Label(value='0 / 6970'))), …

# %%
df_players_male_new['hard_win_perc'] = 100*df_players_male_new['n_wins_hard']/(df_players_male_new['n_wins_hard'] + 
                                                                               df_players_male_new['n_loss_hard'])

# %%
df_players_male_new['n_wins_clay'] = df_players_male_new['name'].parallel_apply(player_clay_wins)
df_players_male_new['n_loss_clay'] = df_players_male_new['name'].parallel_apply(player_clay_losses)
df_players_male_new['clay_win_perc'] = 100*df_players_male_new['n_wins_clay']/(df_players_male_new['n_wins_clay'] + 
                                                                               df_players_male_new['n_loss_clay'])
# Out:
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=6970), Label(value='0 / 6970'))), …
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=6970), Label(value='0 / 6970'))), …

# %%
df_players_male_new['n_wins_grass'] = df_players_male_new['name'].parallel_apply(player_grass_wins)
df_players_male_new['n_loss_grass'] = df_players_male_new['name'].parallel_apply(player_grass_losses)
df_players_male_new['grass_win_perc'] = 100*df_players_male_new['n_wins_grass']/(df_players_male_new['n_wins_grass'] + 
                                                                                 df_players_male_new['n_loss_grass'])
# Out:
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=6970), Label(value='0 / 6970'))), …
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=6970), Label(value='0 / 6970'))), …

# %%
df_players_male_new['n_wins_carpet'] = df_players_male_new['name'].parallel_apply(player_carpet_wins)
df_players_male_new['n_loss_carpet'] = df_players_male_new['name'].parallel_apply(player_carpet_losses)
df_players_male_new['carpet_win_perc'] = 100*df_players_male_new['n_wins_carpet']/(df_players_male_new['n_wins_carpet'] + 
                                                                                   df_players_male_new['n_loss_carpet'])
# Out:
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=6970), Label(value='0 / 6970'))), …
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=6970), Label(value='0 / 6970'))), …

# %%
df_players_male_new.sort_values(by=['n_titles_gs'], ascending=False, inplace=True)

# View the newly created features in the players dataframe
df_players_male_new.head(10)
# Out:
#       player_id name_first name_last hand   birthdate country gender  \
# 4741     104745     Rafael     Nadal    L  19860603.0     ESP   male
# 3818     103819      Roger   Federer    R  19810808.0     SUI   male
# 4919     104925      Novak  Djokovic    R  19870522.0     SRB   male
# 1947     101948       Pete   Sampras    R  19710812.0     USA   male
# 436      100437      Bjorn      Borg    R  19560606.0     SWE   male
# 655      100656       Ivan     Lendl    R  19600307.0     USA   male
# 283      100284      Jimmy   Connors    L  19520902.0     USA   male
# 1735     101736      Andre    Agassi    R  19700429.0     USA   male
# 1061     101062       Mats  Wilander    R  19640822.0     SWE   male
# 1413     101414      Boris    Becker    R  19671122.0     GER   male
#
#       birth_year league            name  n_titles  n_matches  n_wins  \
# 4741        1986    atp    Rafael Nadal        86       1226    1016
# 3818        1981    atp   Roger Federer       103       1525    1250
# 4919        1987    atp  Novak Djokovic        83       1147     955
# 1947        1971    atp    Pete Sampras        65        996     766
# 436         1956    atp      Bjorn Borg        64        789     646
# 655         1960    atp      Ivan Lendl        95       1318    1076
# 283         1952    atp   Jimmy Connors       110       1573    1274
# 1735        1970    atp    Andre Agassi        60       1147     872
# 1061        1964    atp   Mats Wilander        34        794     570
# 1413        1967    atp    Boris Becker        50        941     716
#
#       n_titles_gs  best_rank  n_finals  n_finals_gs  n_top10_wins   win_perc  \
# 4741           20        1.0        38            8           175  82.871126
# 3818           20        1.0        54           11           225  81.967213
# 4919           18        1.0        35           10           220  83.260680
# 1947           14        1.0        24            4           124  76.907631
# 436            11        1.0        24            5            31  81.875792
# 655             8        1.0        52           11           153  81.638847
# 283             8        1.0        51            7            83  80.991736
# 1735            8        1.0        30            7           110  76.024412
# 1061            7        1.0        26            4            65  71.788413
# 1413            6        1.0        28            4           122  76.089267
#
#       n_wins_hard  n_loss_hard  hard_win_perc  n_wins_clay  n_loss_clay  \
# 4741          494          142      77.672956          449           42
# 3818          786          158      83.262712          224           71
# 4919          621          114      84.489796          230           56
# 1947          428          106      80.149813           90           54
# 436           113           37      75.333333          279           48
# 655           395           83      82.635983          329           77
# 283           510          112      81.993569          208           62
# 1735          598          160      78.891821          152           57
# 1061          186           74      71.538462          263           80
# 1413          220           70      75.862069          122           63
#
#       clay_win_perc  n_wins_grass  n_loss_grass  grass_win_perc  \
# 4741      91.446029            71            20       78.021978
# 3818      75.932203           189            27       87.500000
# 4919      80.419580            95            18       84.070796
# 1947      62.500000           102            20       83.606557
# 436       85.321101            72            13       84.705882
# 655       81.034483            81            27       75.000000
# 283       77.037037           174            38       82.075472
# 1735      72.727273            50            18       73.529412
# 1061      76.676385            49            17       74.242424
# 1413      65.945946           116            25       82.269504
#
#       n_wins_carpet  n_loss_carpet  carpet_win_perc
# 4741              2              6        25.000000
# 3818             50             19        72.463768
# 4919              9              4        69.230769
# 1947            146             50        74.489796
# 436             178             42        80.909091
# 655             271             55        83.128834
# 283             350             79        81.585082
# 1735             72             40        64.285714
# 1061             72             53        57.600000
# 1413            258             67        79.384615

# %%
# df_players_male_new.to_csv(r'C:\Users\slaye\Desktop\Python\Tennis\male_players_dataset.csv')
df_players_male_new = pd.read_csv(r'C:\Users\slaye\Desktop\Python\Tennis\male_players_dataset.csv')

# %%
# title winners and finalists and those with best rank < 10
df_players_male_title_wf = df_players_male_new[((df_players_male_new['n_titles'] > 0) | 
                                                (df_players_male_new['n_finals'] > 0)) & 
                                               ((df_players_male_new['best_rank'] <= 10) & 
                                                (df_players_male_new['best_rank'] > 0))]

# %%
print(f'No. of players in reduced set: {len(df_players_male_title_wf)}')
# Out:
# No. of players in reduced set: 145

# %%
df_players_male_title_wf['gs_winner'] = df_players_male_title_wf['n_titles_gs'].apply(lambda x:True if x>0 else False)
df_players_male_title_wf['big_3'] = df_players_male_title_wf['name'].apply(lambda x:True if x in ['Roger Federer', 'Rafael Nadal', 'Novak Djokovic'] else False)

# %%
# df_players_male_title_wf.to_csv(r'C:\Users\slaye\Desktop\Python\Tennis\best_male_players_dataset.csv')
df_players_male_title_wf = pd.read_csv(r'C:\Users\slaye\Desktop\Python\Tennis\best_male_players_dataset.csv')

# %%
df_players_male_title_wf['n_finals_total'] = df_players_male_title_wf['n_finals'] + df_players_male_title_wf['n_titles']

# %% [markdown]
# ### Male players: Titles vs Finals <a class="anchor" id="101-bullet"></a>

# %%
from IPython.display import Image

# %%
fig = px.scatter(df_players_male_title_wf, x='n_finals_total', y='n_titles', color='gs_winner', symbol='gs_winner',
                hover_data=['name', 'win_perc', 'best_rank'],
                labels={'n_finals_total': 'No. of title finals played', 
                        'n_titles': 'No. of titles won', 
                        'gs_winner': 'Grand Slam Winner?'},
                title='Male players: Titles vs Finals')

# Display interactive image as static due to constraints around rendering interactive images in webpages and github
# fig.show("notebook")
Image(fig.to_image(format="png", width=1000, height=500, engine="kaleido"))

# %% [markdown]
# ### Male players: Best Grand Slam performers <a class="anchor" id="102-bullet"></a>

# %%
df_players_male_title_wf['n_finals_gs_total'] = df_players_male_title_wf['n_finals_gs']+df_players_male_title_wf['n_titles_gs']

# %%
fig = px.scatter(df_players_male_title_wf, x='n_finals_gs_total', y='n_titles_gs', color='big_3',
                hover_data=['name', 'best_rank', 'win_perc'],
                labels={'n_finals_gs_total': 'No. of Grand Slam finals played', 
                        'n_titles_gs': 'No. of Grand Slam titles won', 
                        'big_3': 'Big 3 player?'},
                title='Male players: Best Grand Slam performers')

# Display interactive image as static due to constraints around rendering interactive images in webpages and github
# fig.show("notebook")
Image(fig.to_image(format="png", width=1000, height=500, engine="kaleido"))

# %% [markdown]
# ### Male players: Best Hard Court performers <a class="anchor" id="103-bullet"></a>

# %%
df_players_male_title_wf['n_hard_total'] = df_players_male_title_wf['n_loss_hard'] + df_players_male_title_wf['n_wins_hard']

# %%
fig = px.scatter(df_players_male_title_wf, x='n_hard_total', y='n_wins_hard', color='big_3',
                hover_data=['name', 'hard_win_perc'],
                labels={'n_hard_total': '# hard court matches played', 
                        'n_wins_hard': '# hard court matches won', 
                        'big_3': 'Big 3 player?'},
                title='Male players: Best Hard Court performers')

# Display interactive image as static due to constraints around rendering interactive images in webpages and github
# fig.show("notebook")
Image(fig.to_image(format="png", width=1000, height=500, engine="kaleido"))

# %% [markdown]
# ### Male players: Best Clay Court performers <a class="anchor" id="104-bullet"></a>

# %%
df_players_male_title_wf['n_clay_total'] = df_players_male_title_wf['n_wins_clay'] + df_players_male_title_wf['n_loss_clay']

# %%
fig = px.scatter(df_players_male_title_wf, x='n_clay_total', y='n_wins_clay', color='big_3',
                hover_data=['name', 'clay_win_perc'],
                labels={'n_clay_total': '# clay court matches played', 
                        'n_wins_clay': '# clay court matches won', 
                        'big_3': 'Big 3 player?'},
                title='Male players: Best Clay Court performers')

# Display interactive image as static due to constraints around rendering interactive images in webpages and github
# fig.show("notebook")
Image(fig.to_image(format="png", width=1000, height=500, engine="kaleido"))

# %% [markdown]
# ### Male players: Best Grass Court performers <a class="anchor" id="105-bullet"></a>

# %%
df_players_male_title_wf['n_grass_total'] = df_players_male_title_wf['n_wins_grass'] + df_players_male_title_wf['n_loss_grass']

# %%
fig = px.scatter(df_players_male_title_wf, x='n_grass_total', y='n_wins_grass', color='big_3',
                hover_data=['name', 'grass_win_perc'],
                labels={'n_grass_total': '# grass court matches played', 
                        'n_wins_grass': '# grass court matches won', 
                        'big_3': 'Big 3 player?'},
                title='Male players: Best Grass Court performers')

# Display interactive image as static due to constraints around rendering interactive images in webpages and github
# fig.show("notebook")
Image(fig.to_image(format="png", width=1000, height=500, engine="kaleido"))

# %% [markdown]
# ### Male players: Best Carpet Court performers <a class="anchor" id="106-bullet"></a>

# %%
df_players_male_title_wf['n_carpet_total'] = df_players_male_title_wf['n_wins_carpet']+df_players_male_title_wf['n_loss_carpet']

# %%
fig = px.scatter(df_players_male_title_wf, x='n_carpet_total', y='n_wins_carpet', color='big_3',
                hover_data=['name', 'carpet_win_perc'],
                labels={'n_carpet_total': '# carpet court matches played', 
                        'n_wins_carpet': '# carpet court matches won', 
                        'big_3': 'Big 3 player?'},
                title='Male players: Best Carpet Court performers')

# Display interactive image as static due to constraints around rendering interactive images in webpages and github
# fig.show("notebook")
Image(fig.to_image(format="png", width=1000, height=500, engine="kaleido"))

# %% [markdown]
# ### Male players: Hard vs Clay court performers <a class="anchor" id="107-bullet"></a>

# %%
fig = px.scatter(df_players_male_title_wf, x='hard_win_perc', y='clay_win_perc', color='big_3',
                hover_data=['name'],
                labels={'hard_win_perc': 'hard court win %', 'clay_win_perc': 'clay court win %', 'big_3': 'Big 3 player?'},
                title='Male players: Hard vs Clay court performers')

fig.add_shape(type='line',
                x0=0,
                y0=0,
                x1=100,
                y1=100,
                line=dict(color='Black',),
                xref='x',
                yref='y'
)

fig.update_xaxes(range=[0, 100])
fig.update_yaxes(
    range=[0,100],
    scaleanchor="x",
    scaleratio=1,
  )

# Display interactive image as static due to constraints around rendering interactive images in webpages and github
# fig.show("notebook")
Image(fig.to_image(format="png", width=1000, height=500, engine="kaleido"))

# %% [markdown]
# ### Male players: Hard vs Grass court performers <a class="anchor" id="108-bullet"></a>

# %%
fig = px.scatter(df_players_male_title_wf, x='hard_win_perc', y='grass_win_perc', color='big_3',
                hover_data=['name'],
                labels={'hard_win_perc': 'hard court win %', 'grass_win_perc': 'grass court win %', 'big_3': 'Big 3 player?'},
                title='Male players: Hard vs Grass court performers')

fig.update_yaxes(
    range=[0,100],
    scaleanchor="x",
    scaleratio=1,
  )
fig.update_xaxes(range=[0, 100])

fig.add_shape(type='line',
                x0=0,
                y0=0,
                x1=100,
                y1=100,
                line=dict(color='Black',),
                xref='x',
                yref='y'
)

# Display interactive image as static due to constraints around rendering interactive images in webpages and github
# fig.show("notebook")
Image(fig.to_image(format="png", width=1000, height=500, engine="kaleido"))

# %% [markdown]
# ### Male players: Grass vs Clay court performers <a class="anchor" id="109-bullet"></a>

# %%
fig = px.scatter(df_players_male_title_wf, x='grass_win_perc', y='clay_win_perc', color='big_3',
                hover_data=['name'],
                labels={'grass_win_perc': 'grass court win %', 'clay_win_perc': 'clay court win %', 'big_3': 'Big 3 player?'},
                title='Male players: Grass vs Clay court performers')

fig.update_xaxes(range=[0, 100])
fig.update_yaxes(
    range=[0,100],
    scaleanchor="x",
    scaleratio=1,
  )

fig.add_shape(type='line',
                x0=0,
                y0=0,
                x1=100,
                y1=100,
                line=dict(color='Black',),
                xref='x',
                yref='y'
)

# Display interactive image as static due to constraints around rendering interactive images in webpages and github
# fig.show("notebook")
Image(fig.to_image(format="png", width=1000, height=500, engine="kaleido"))

# %% [markdown]
# ### Quasi Simpson Paradox <a class="anchor" id="110-bullet"></a>
#
# This is when a tennis player wins a match despite winning fewer games or points than the opponent!

# %%
# QSP paradox - winning with fewer games than opponent

def get_winner_ngames(score):
    sets = str(score).split(' ')
    n = 0
    for s in sets:
        games = s.split('-')
        try:
            games_w = games[0]
            if '(' in games_w:
                games_w = games_w[0]
            n += int(games_w)
        except:
            n += 0
    return n

def get_loser_ngames(score):
    sets = str(score).split(' ')
    n = 0
    for s in sets:
        games = s.split('-')
        try:
            games_l = games[1]
            if '(' in games_l:
                games_l = games_l[0]
            n += int(games_l)
        except:
            n += 0
    return n

def get_winner_nsets(score):
    sets = str(score).split(' ')
    n = 0
    for s in sets:
        games = s.split('-')
            
        try:
            games_w = games[0]
            if '(' in games_w:
                games_w = games_w[0]
            
            games_l = games[1]
            if '(' in games_l:
                games_l = games_l[0]
            
            winner_ngames = int(games_w)
            loser_ngames = int(games_l)
            if winner_ngames > loser_ngames:
                n += 1
        except:
            n += 0
    return n

# %%
df_matches['winner_ngames'] = df_matches['score'].apply(get_winner_ngames)
df_matches['loser_ngames'] = df_matches['score'].apply(get_loser_ngames)
df_matches['winner_nsets'] = df_matches['score'].apply(get_winner_nsets)

df_matches['delta_w_l_ngames'] = df_matches['winner_ngames'] - df_matches['loser_ngames']
df_matches['match_type'] = df_matches['winner_nsets'].apply(lambda x:'best of 5' if x==3 else 'best of 3')

# %%
df_matches.head(10)
# Out:
#   tourney_id tourney_name surface draw_size tourney_level tourney_date  \
# 0  2019-M020     Brisbane    Hard        32             A   2018-12-31
# 1  2019-M020     Brisbane    Hard        32             A   2018-12-31
# 2  2019-M020     Brisbane    Hard        32             A   2018-12-31
# 3  2019-M020     Brisbane    Hard        32             A   2018-12-31
# 4  2019-M020     Brisbane    Hard        32             A   2018-12-31
# 5  2019-M020     Brisbane    Hard        32             A   2018-12-31
# 6  2019-M020     Brisbane    Hard        32             A   2018-12-31
# 7  2019-M020     Brisbane    Hard        32             A   2018-12-31
# 8  2019-M020     Brisbane    Hard        32             A   2018-12-31
# 9  2019-M020     Brisbane    Hard        32             A   2018-12-31
#
#    match_num  winner_id winner_seed winner_entry         winner_name  \
# 0        300     105453         2.0          NaN       Kei Nishikori
# 1        299     106421         4.0          NaN     Daniil Medvedev
# 2        298     105453         2.0          NaN       Kei Nishikori
# 3        297     104542         NaN           PR  Jo-Wilfried Tsonga
# 4        296     106421         4.0          NaN     Daniil Medvedev
# 5        295     104871         NaN          NaN       Jeremy Chardy
# 6        294     105453         2.0          NaN       Kei Nishikori
# 7        293     104542         NaN           PR  Jo-Wilfried Tsonga
# 8        292     200282         7.0          NaN      Alex De Minaur
# 9        291     106421         4.0          NaN     Daniil Medvedev
#
#   winner_hand  winner_ht winner_ioc  winner_age  loser_id loser_seed  \
# 0           R      178.0        JPN   29.004791    106421        4.0
# 1           R        NaN        RUS   22.885695    104542        NaN
# 2           R      178.0        JPN   29.004791    104871        NaN
# 3           R      188.0        FRA   33.705681    200282        7.0
# 4           R        NaN        RUS   22.885695    105683        5.0
# 5           R      188.0        FRA   31.882272    106034        NaN
# 6           R      178.0        JPN   29.004791    105777        6.0
# 7           R      188.0        FRA   33.705681    106121        NaN
# 8           R        NaN        AUS   19.868583    111442        NaN
# 9           R        NaN        RUS   22.885695    104918        NaN
#
#   loser_entry          loser_name loser_hand  loser_ht loser_ioc  loser_age  \
# 0         NaN     Daniil Medvedev          R       NaN       RUS  22.885695
# 1          PR  Jo-Wilfried Tsonga          R     188.0       FRA  33.705681
# 2         NaN       Jeremy Chardy          R     188.0       FRA  31.882272
# 3         NaN      Alex De Minaur          R       NaN       AUS  19.868583
# 4         NaN        Milos Raonic          R     196.0       CAN  28.010951
# 5           Q   Yasutaka Uchiyama          R       NaN       JPN  26.403833
# 6         NaN     Grigor Dimitrov          R     188.0       BUL  27.627652
# 7          LL         Taro Daniel          R       NaN       JPN  25.924709
# 8         NaN     Jordan Thompson          R       NaN       AUS  24.698152
# 9          PR         Andy Murray          R     190.0       GBR  31.630390
#
#             score  best_of round  minutes  w_ace  w_df  w_svpt  w_1stIn  \
# 0     6-4 3-6 6-2        3     F    124.0    3.0   3.0    77.0     44.0
# 1      7-6(6) 6-2        3    SF     82.0   10.0   1.0    52.0     33.0
# 2         6-2 6-2        3    SF     66.0    2.0   2.0    47.0     33.0
# 3      6-4 7-6(2)        3    QF    106.0   12.0   2.0    68.0     43.0
# 4  6-7(2) 6-3 6-4        3    QF    129.0   12.0   3.0   105.0     68.0
# 5  6-4 3-6 7-6(4)        3    QF    127.0   10.0   8.0    94.0     58.0
# 6         7-5 7-5        3    QF    100.0    5.0   2.0    59.0     47.0
# 7      7-6(5) 6-3        3   R16    100.0   11.0   3.0    64.0     37.0
# 8         6-4 6-2        3   R16     80.0    1.0   1.0    49.0     38.0
# 9         7-5 6-2        3   R16     81.0   16.0   2.0    54.0     34.0
#
#    w_1stWon  w_2ndWon  w_SvGms  w_bpSaved  w_bpFaced  l_ace  l_df  l_svpt  \
# 0      31.0      17.0     13.0        3.0        6.0    8.0   6.0   100.0
# 1      28.0      14.0     10.0        0.0        1.0   17.0   2.0    77.0
# 2      26.0       9.0      8.0        2.0        2.0   10.0   3.0    46.0
# 3      34.0      15.0     11.0        4.0        5.0    1.0   2.0    81.0
# 4      48.0      25.0     16.0        8.0        8.0   29.0   5.0    94.0
# 5      44.0      18.0     16.0        4.0        8.0   12.0   6.0    90.0
# 6      37.0       9.0     12.0        0.0        1.0    8.0   5.0    80.0
# 7      30.0      11.0     10.0        4.0        7.0    3.0   7.0    85.0
# 8      29.0       8.0      9.0        0.0        0.0    5.0   0.0    56.0
# 9      27.0      13.0     10.0        0.0        1.0    6.0   1.0    60.0
#
#    l_1stIn  l_1stWon  l_2ndWon  l_SvGms  l_bpSaved  l_bpFaced  winner_rank  \
# 0     54.0      34.0      20.0     14.0       10.0       15.0          9.0
# 1     52.0      36.0       7.0     10.0       10.0       13.0         16.0
# 2     27.0      15.0       6.0      8.0        1.0        5.0          9.0
# 3     60.0      38.0       9.0     11.0        4.0        6.0        239.0
# 4     56.0      46.0      19.0     15.0        2.0        4.0         16.0
# 5     54.0      40.0      18.0     15.0        6.0        9.0         40.0
# 6     53.0      37.0      13.0     12.0        6.0        9.0          9.0
# 7     51.0      34.0      11.0     11.0        6.0       11.0        239.0
# 8     39.0      30.0       3.0      9.0        3.0        6.0         31.0
# 9     39.0      27.0       7.0     10.0        2.0        6.0         16.0
#
#    winner_rank_points  loser_rank  loser_rank_points league  winner_ngames  \
# 0              3590.0        16.0             1977.0    atp             15
# 1              1977.0       239.0              200.0    atp             13
# 2              3590.0        40.0             1050.0    atp             12
# 3               200.0        31.0             1298.0    atp             13
# 4              1977.0        18.0             1855.0    atp             18
# 5              1050.0       185.0              275.0    atp             16
# 6              3590.0        19.0             1835.0    atp             14
# 7               200.0        77.0              691.0    atp             13
# 8              1298.0        72.0              715.0    atp             12
# 9              1977.0       240.0              200.0    atp             13
#
#    loser_ngames  winner_nsets  delta_w_l_ngames match_type
# 0            12             2                 3  best of 3
# 1             8             2                 5  best of 3
# 2             4             2                 8  best of 3
# 3            10             2                 3  best of 3
# 4            14             2                 4  best of 3
# 5            16             2                 0  best of 3
# 6            10             2                 4  best of 3
# 7             9             2                 4  best of 3
# 8             6             2                 6  best of 3
# 9             7             2                 6  best of 3

# %%
df_matches['delta_w_l_ngames'].describe()
# Out:
# count    373436.000000
# mean          5.685585
# std           3.170960
# min         -88.000000
# 25%           4.000000
# 50%           6.000000
# 75%           8.000000
# max         606.000000
# Name: delta_w_l_ngames, dtype: float64

# %%
df_matches_2 = df_matches[(df_matches['delta_w_l_ngames']<=30) & (df_matches['delta_w_l_ngames']>=-10)]

# %%
fig, ax = plt.subplots(figsize=(10,7))
sns.histplot(data=df_matches_2[df_matches_2['league']=='atp'], x='delta_w_l_ngames', hue='match_type', element='step',
            stat="density", common_norm=False, kde=True, bins=20, ax=ax,
            kde_kws={'bw_adjust':2})
ax.set_title('ATP')
ax.set_xlabel('Delta between winner and loser games won')
# Out:
# Text(0.5, 0, 'Delta between winner and loser games won')

# %%
fig, ax = plt.subplots(figsize=(10,7))
sns.histplot(data=df_matches_2[df_matches_2['league']=='wta'], x='delta_w_l_ngames', hue='match_type', element='step',
            stat="density", common_norm=False, kde=True, bins=20, ax=ax,
            kde_kws={'bw_adjust':2})
ax.set_title('WTA')
ax.set_xlabel('Delta between winner and loser games won')
# Out:
# Text(0.5, 0, 'Delta between winner and loser games won')

# %%
n1 = len(df_matches_2[(df_matches_2['delta_w_l_ngames']<0) & (df_matches_2['match_type']=='best of 3') & (df_matches_2['league']=='atp')])
n2 = len(df_matches_2[(df_matches_2['delta_w_l_ngames']<0) & (df_matches_2['match_type']=='best of 5') & (df_matches_2['league']=='atp')])
n1_t = len(df_matches_2[(df_matches_2['match_type']=='best of 3') & (df_matches_2['league']=='atp')])
n2_t = len(df_matches_2[(df_matches_2['match_type']=='best of 5') & (df_matches_2['league']=='atp')])

print(f'ATP: Frac of best of 3 matches when winner had won less games than loser: {n1/n1_t:.2%}')
print(f'ATP: Frac of best of 5 matches when winner had won less games than loser: {n2/n2_t:.2%}')

n_gs = len(df_matches_2[(df_matches_2['delta_w_l_ngames']<0) & (df_matches_2['tourney_level']=='G') & (df_matches_2['league']=='atp')])
n_gs_t = len(df_matches_2[(df_matches_2['tourney_level']=='G') & (df_matches_2['league']=='atp')])

n_ngs = len(df_matches_2[(df_matches_2['delta_w_l_ngames']<0) & ~(df_matches_2['tourney_level']=='G') & (df_matches_2['league']=='atp')])
n_ngs_t = len(df_matches_2[~(df_matches_2['tourney_level']=='G') & (df_matches_2['league']=='atp')])

print(f'ATP: Frac of GS matches when winner had won less games than loser: {n_gs/n_gs_t:.2%}')
print(f'ATP: Frac of non-GS matches when winner had won less games than loser: {n_ngs/n_ngs_t:.2%}')

n1 = len(df_matches_2[(df_matches_2['delta_w_l_ngames']<0) & (df_matches_2['match_type']=='best of 3') & (df_matches_2['league']=='wta')])
n2 = len(df_matches_2[(df_matches_2['delta_w_l_ngames']<0) & (df_matches_2['match_type']=='best of 5') & (df_matches_2['league']=='wta')])
n1_t = len(df_matches_2[(df_matches_2['match_type']=='best of 3') & (df_matches_2['league']=='wta')])
n2_t = len(df_matches_2[(df_matches_2['match_type']=='best of 5') & (df_matches_2['league']=='wta')])

print(f'WTA: Frac of best of 3 matches when winner had won less games than loser: {n1/n1_t:.2%}')
print(f'WTA: Frac of best of 5 matches when winner had won less games than loser: {n2/n2_t:.2%}')

n_gs = len(df_matches_2[(df_matches_2['delta_w_l_ngames']<0) & (df_matches_2['tourney_level']=='G') & (df_matches_2['league']=='wta')])
n_gs_t = len(df_matches_2[(df_matches_2['tourney_level']=='G') & (df_matches_2['league']=='wta')])

n_ngs = len(df_matches_2[(df_matches_2['delta_w_l_ngames']<0) & ~(df_matches_2['tourney_level']=='G') & (df_matches_2['league']=='wta')])
n_ngs_t = len(df_matches_2[~(df_matches_2['tourney_level']=='G') & (df_matches_2['league']=='wta')])

print(f'WTA: Frac of GS matches when winner had won less games than loser: {n_gs/n_gs_t:.2%}')
print(f'WTA: Frac of non-GS matches when winner had won less games than loser: {n_ngs/n_ngs_t:.2%}')
# Out:
# ATP: Frac of best of 3 matches when winner had won less games than loser: 2.04%
# ATP: Frac of best of 5 matches when winner had won less games than loser: 1.77%
# ATP: Frac of GS matches when winner had won less games than loser: 1.94%
# ATP: Frac of non-GS matches when winner had won less games than loser: 1.99%
# WTA: Frac of best of 3 matches when winner had won less games than loser: 1.29%
# WTA: Frac of best of 5 matches when winner had won less games than loser: 0.00%
# WTA: Frac of GS matches when winner had won less games than loser: 1.10%
# WTA: Frac of non-GS matches when winner had won less games than loser: 1.32%

# %%
df_matches_2[(df_matches_2['league']=='wta') & (df_matches_2['match_type']=='best of 5')]
# Out:
#                     tourney_id                  tourney_name surface  \
# 197008  1989-W-WT-USA-25A-1989  Virginia Slims Championships  Carpet
# 198716  1988-W-WT-PUR-01A-1988                      San Juan    Hard
# 199865  1988-W-WT-USA-26A-1988  Virginia Slims Championships  Carpet
# 201182               1963-1106        Casablanca Consolation    Clay
# 207976               1973-1147         Battle of the Sexes 2  Carpet
# 211860  1998-W-WT-USA-12A-1998        WTA Tour Championships  Carpet
# 212218  1998-W-WT-USA-06A-1998                      Stanford    Hard
# 223765               1958-1159             Manchester-on-Sea   Grass
# 234450               1965-1109                 Roland Garros    Clay
# 307725  1997-W-WT-USA-11A-1997        WTA Tour Championships  Carpet
# 310698  1996-W-WT-USA-06A-1996               Manhattan Beach    Hard
# 310826  1996-W-WT-USA-11A-1996        WTA Tour Championships  Carpet
# 319672               1955-1162                   Paris Natls     NaN
# 324151  1994-W-WT-SUI-01A-1994                       Lucerne    Clay
# 324196  1994-W-WT-USA-08A-1994                   Hilton Head    Clay
# 324653  1994-W-WT-USA-16A-1994  Virginia Slims Championships  Carpet
# 327523  1980-W-WT-USA-28A-1980                        Tucson  Carpet
# 331377  1981-W-WT-USA-19A-1981                        Mahwah    Hard
# 334693  1995-W-WT-USA-13A-1995        WTA Tour Championships  Carpet
# 342199  1991-W-WT-USA-23A-1991  Virginia Slims Championships  Carpet
# 342896  1991-W-WT-JPN-02A-1991                 Tokyo Outdoor    Hard
# 344703  1985-W-WT-USA-01A-1985           Ginny Championships    Hard
# 345048  1985-W-WT-USA-12A-1985  Virginia Slims Championships  Carpet
# 347585  1984-W-WT-USA-12A-1984  Virginia Slims Championships  Carpet
# 350084  1990-W-WT-USA-24A-1990  Virginia Slims Championships  Carpet
# 353434  1979-W-SL-USA-01A-1979                       US Open    Hard
# 353780  1979-W-WT-GBR-02A-1979                    Eastbourne   Grass
# 358375  1986-W-WT-FRG-02A-1986                   Filderstadt  Carpet
# 359307  1986-W-WT-USA-10A-1986                        Dallas  Carpet
# 359336  1986-W-WT-USA-11A-1986  Virginia Slims Championships  Carpet
# 360046  1986-W-WT-USA-32A-1986  Virginia Slims Championships  Carpet
# 361760  1992-W-WT-USA-17A-1992  Virginia Slims Championships  Carpet
# 362257  1992-W-WT-AUS-01A-1992                        Sydney    Hard
# 364566  1993-W-WT-USA-16A-1993  Virginia Slims Championships  Carpet
# 367304  1987-W-WT-USA-02A-1987                 San Francisco    Hard
# 368292  1987-W-WT-USA-26A-1987  Virginia Slims Championships  Carpet
# 370870  1978-W-WT-USA-18A-1978                       Atlanta  Carpet
# 371052  1978-W-WT-CAN-02A-1978                      Montreal    Hard
# 371773  1978-W-WT-USA-21A-1978                       Oldsmar    Hard
# 371836  1978-W-WT-USA-15A-1978                  Indianapolis    Clay
#
#        draw_size tourney_level tourney_date  match_num  winner_id winner_seed  \
# 197008      16.0             W   1989-11-13         15     200414         1.0
# 198716      32.0             W   1988-10-10          2     200507         NaN
# 199865      16.0             W   1988-11-14         15     200572         4.0
# 201182       0.0             W   1963-05-31          3     200173         NaN
# 207976       0.0             E   1973-09-20          1     200190         NaN
# 211860      16.0             W   1998-11-16         15     200001         2.0
# 212218      28.0             W   1998-07-27         11     200070         NaN
# 223765         0             W   1958-08-12          2     226423         NaN
# 234450       0.0             G   1965-05-17         37     201098         NaN
# 307725        16             W   1997-11-17         15     200539         2.0
# 310698        56             W   1996-08-12          2     200748         NaN
# 310826        16             W   1996-11-18         15     200414         1.0
# 319672       0.0             W   1955-07-14         23     216613         NaN
# 324151      28.0             W   1994-05-16         20     200086         2.0
# 324196      56.0             W   1994-03-28          7     200667         NaN
# 324653      16.0             W   1994-11-14         15     200572         NaN
# 327523      32.0             W   1980-12-15         23     200226         NaN
# 331377      56.0             W   1981-08-24          8     200330         NaN
# 334693      16.0             W   1995-11-13         15     200414         1.0
# 342199      16.0             W   1991-11-18         15     200652         1.0
# 342896      32.0             W   1991-04-08         21     200574         6.0
# 344703      14.0             W   1985-01-02          6     200463         2.0
# 345048      16.0             W   1985-03-18         15     200293         1.0
# 347585      16.0             W   1984-02-28         15     200293         1.0
# 350084        16             W   1990-11-12         15     200652         2.0
# 353434        96             G   1979-08-28         86     200397         3.0
# 353780        64             W   1979-06-18         53     200372         NaN
# 358375        32             W   1986-10-13          7     200464         NaN
# 359307        56             W   1986-03-10         41     200293         1.0
# 359336        16             W   1986-03-17         15     200293         1.0
# 360046        16             W   1986-11-17         15     200293         1.0
# 361760      16.0             W   1992-11-16         15     200652         1.0
# 362257      56.0             W   1992-01-06         28     200404         7.0
# 364566      16.0             W   1993-11-15         15     200414         1.0
# 367304      32.0             W   1987-02-09         24     200419         2.0
# 368292      16.0             W   1987-11-16         15     200414         1.0
# 370870      32.0             W   1978-09-25         11     200393         NaN
# 371052      32.0             W   1978-09-18          6     200962         NaN
# 371773      32.0             W   1978-11-06         17     200293         NaN
# 371836      48.0             W   1978-08-07         33     200953         NaN
#
#        winner_entry            winner_name winner_hand  winner_ht winner_ioc  \
# 197008          NaN            Steffi Graf           R        NaN        GER
# 198716          NaN           Kathrin Keil           U        NaN        USA
# 199865          NaN      Gabriela Sabatini           R        NaN        ARG
# 201182          NaN            Kaye Dening           U        NaN        AUS
# 207976          NaN       Billie Jean King           R        NaN        USA
# 211860          NaN         Martina Hingis           R      170.0        SUI
# 212218          NaN      Anne Gaelle Sidot           L        NaN        FRA
# 223765          NaN        Barbara Benigni           U        NaN        USA
# 234450          NaN           Mimi Wheeler           U      155.0        USA
# 307725          NaN           Jana Novotna           R        NaN        CZE
# 310698           WC         Venus Williams           R      185.0        USA
# 310826          NaN            Steffi Graf           R        NaN        GER
# 319672          NaN           Maud Galtier           U        NaN        FRA
# 324151          NaN      Magdalena Maleeva           R      168.0        BUL
# 324196          NaN     Ines Gorrochategui           R        NaN        ARG
# 324653          NaN      Gabriela Sabatini           R        NaN        ARG
# 327523          NaN          Mona Guerrant           U        NaN        USA
# 331377          NaN             Sue Saliba           U        NaN        AUS
# 334693          NaN            Steffi Graf           R        NaN        GER
# 342199          NaN           Monica Seles           L        NaN        USA
# 342896          NaN         Eva Sviglerova           U        NaN        CZE
# 344703          NaN         Terry Holladay           U        NaN        USA
# 345048          NaN    Martina Navratilova           L      173.0        USA
# 347585          NaN    Martina Navratilova           L      173.0        USA
# 350084          NaN           Monica Seles           L        NaN        USA
# 353434          NaN           Tracy Austin           R        NaN        USA
# 353780          NaN          Bettina Bunge           U        NaN        GER
# 358375          NaN        Ann Henricksson           U        NaN        USA
# 359307          NaN    Martina Navratilova           L      173.0        USA
# 359336          NaN    Martina Navratilova           L      173.0        USA
# 360046          NaN    Martina Navratilova           L      173.0        USA
# 361760          NaN           Monica Seles           L        NaN        USA
# 362257          NaN          Zina Garrison           U        NaN        USA
# 364566          NaN            Steffi Graf           R        NaN        GER
# 367304          NaN  Kathy Rinaldi Stunkel           U        NaN        USA
# 368292          NaN            Steffi Graf           R        NaN        GER
# 370870          NaN         Lea Antonoplis           U        NaN        USA
# 371052          NaN       Patricia Medrado           U        NaN        BRA
# 371773          NaN    Martina Navratilova           L      173.0        USA
# 371836          NaN          Viviana Segal           U        NaN        ARG
#
#         winner_age  loser_id loser_seed loser_entry               loser_name  \
# 197008   20.416153    200293        2.0         NaN      Martina Navratilova
# 198716   25.867214    201019        NaN         NaN           Melissa Gurney
# 199865   18.499658    200360        5.0         NaN              Pam Shriver
# 201182         NaN    212441        NaN         NaN       Jacqueline Morales
# 207976   29.828884    113190        NaN         NaN              Bobby Riggs
# 211860   18.127310    200128          1         NaN        Lindsay Davenport
# 212218   19.008898    200735        NaN         NaN               Miho Saeki
# 223765         NaN    224175        NaN         NaN             Ruth Jeffery
# 234450   26.217659    200850        NaN         NaN          Monique Di Maso
# 307725   29.125257    200096        7.0         NaN              Mary Pierce
# 310698   16.153320    200718        NaN         NaN       Ludmila Richterova
# 310826   27.430527    200001        7.0         NaN           Martina Hingis
# 319672         NaN    225583        NaN         NaN         Ginette Bucaille
# 324151   19.123888    200040        NaN         NaN           Anna Smashnova
# 324196   20.788501    200640        NaN          WC             Mercedes Paz
# 324653   24.498289    200128        7.0         NaN        Lindsay Davenport
# 327523   32.046543    200283        7.0         NaN           Pam Teeguarden
# 331377   23.860370    200363        NaN         NaN         Hana Strachonova
# 334693   26.414784    200081        NaN         NaN               Anke Huber
# 342199   17.960301    200293        4.0         NaN      Martina Navratilova
# 342896   19.737166    200057        NaN         NaN            Erika De Lone
# 344703   29.097878    200438        NaN         NaN      Michaela Washington
# 345048   28.413415    200377        4.0         NaN            Helena Sukova
# 347585   27.362081    200259        2.0         NaN              Chris Evert
# 350084   16.944559    200572        3.0         NaN        Gabriela Sabatini
# 353434   16.709103    200389       11.0         NaN             Kathy Jordan
# 353780   16.013689    200758        NaN           Q                Rayni Fox
# 358375   26.951403    200487        NaN           Q                Eva Krapl
# 359307   29.390828    200375       13.0         NaN           Barbara Potter
# 359336   29.409993    200348        5.0         NaN          Hana Mandlikova
# 360046   30.080767    200414        2.0         NaN              Steffi Graf
# 361760   18.956879    200293        4.0         NaN      Martina Navratilova
# 362257   28.139630    200495        NaN         NaN           Akiko Kijimuta
# 364566   24.421629    200017        2.0         NaN  Arantxa Sanchez Vicario
# 367304   19.882272    200387        NaN         NaN               Anne White
# 368292   18.422998    200572        NaN         NaN        Gabriela Sabatini
# 370870   19.679671    200379        NaN           Q              Paula Smith
# 371052   21.809719    200256        NaN         NaN              Chris Oneil
# 371773   22.050650    200976        NaN         NaN           Stacy Margolin
# 371836   20.292950    200379        NaN         NaN              Paula Smith
#
#        loser_hand  loser_ht loser_ioc  loser_age                score  \
# 197008          L     173.0       USA  33.070500      6-4 7-5 2-6 6-2
# 198716          U       NaN       USA  19.296372          6-2 6-3 6-1
# 199865          R       NaN       USA  26.365503          7-5 6-2 6-2
# 201182        NaN       NaN       MAR        NaN          6-1 7-5 6-3
# 207976          U       NaN       USA        NaN          6-4 6-3 6-3
# 211860          R     189.0       USA  22.439425      7-5 6-4 4-6 6-2
# 212218          R       NaN       JPN  22.357290          7-6 6-2 6-3
# 223765          U       NaN       USA  23.879535          6-4 6-4 6-2
# 234450          U       NaN       ITA  19.997262      5-7 6-1 6-1 8-6
# 307725          R     178.0       FRA  22.839151          7-6 6-2 6-3
# 310698          U       NaN       CZE  19.433265          7-6 6-3 6-2
# 310826          R     170.0       SUI  16.134155  6-3 4-6 6-0 4-6 6-0
# 319672          U       NaN       FRA  29.464750          7-0 6-3 6-3
# 324151          R       NaN       ISR  17.831622          6-3 6-1 6-1
# 324196          U       NaN       ARG  27.750856          6-1 6-3 7-5
# 324653          R     189.0       USA  18.433949          6-3 6-2 6-4
# 327523          U       NaN       USA  29.664613          6-4 7-6 6-0
# 331377          U       NaN       SUI  20.640657          6-1 6-3 6-4
# 334693          R       NaN       GER  20.941821  6-1 2-6 6-1 4-6 6-3
# 342199          L     173.0       USA  35.082820      6-4 3-6 7-5 6-0
# 342896          R       NaN       USA  18.480493          6-3 6-2 6-3
# 344703          U       NaN       USA  18.847365          6-4 6-3 6-2
# 345048          R       NaN       CZE  20.062971          6-3 7-5 6-4
# 347585          R       NaN       USA  29.188227          6-3 7-5 6-1
# 350084          R       NaN       ARG  20.492813  6-4 5-7 3-6 6-4 6-2
# 353434          U       NaN       USA  19.734428          6-4 6-1 7-6
# 353780          U       NaN       USA  23.066393          7-6 6-3 8-6
# 358375          U       NaN       SUI  20.739220          8-6 7-6 6-3
# 359307          U       NaN       USA  24.380561          6-4 7-6 6-1
# 359336          R       NaN       AUS  24.071184      6-2 6-0 3-6 6-1
# 360046          R       NaN       GER  17.426420          7-6 6-3 6-2
# 361760          L     173.0       USA  36.079398          7-5 6-3 6-1
# 362257          U       NaN       JPN  23.682409          6-4 6-3 6-2
# 364566          R       NaN       ESP  21.911020      6-1 6-4 3-6 6-1
# 367304          U       NaN       USA  25.366188          6-0 6-1 7-6
# 368292          R       NaN       ARG  17.503080      4-6 6-4 6-0 6-4
# 370870          U       NaN       USA  21.705681          6-4 7-6 6-3
# 371052          R       NaN       AUS  22.499658          6-2 7-5 6-3
# 371773          U       NaN       USA  19.589322          6-2 6-3 6-2
# 371836          U       NaN       USA  21.571526          7-6 6-1 6-3
#
#         best_of round  minutes  w_ace  w_df  w_svpt  w_1stIn  w_1stWon  \
# 197008        3     F      NaN    NaN   NaN     NaN      NaN       NaN
# 198716        3   R32      NaN    NaN   NaN     NaN      NaN       NaN
# 199865        3     F      NaN    NaN   NaN     NaN      NaN       NaN
# 201182        3     F      NaN    NaN   NaN     NaN      NaN       NaN
# 207976        3    RR      NaN    NaN   NaN     NaN      NaN       NaN
# 211860        3     F      NaN    NaN   NaN     NaN      NaN       NaN
# 212218        3   R32      NaN    NaN   NaN     NaN      NaN       NaN
# 223765        3   R32      NaN    NaN   NaN     NaN      NaN       NaN
# 234450        3   R64      NaN    NaN   NaN     NaN      NaN       NaN
# 307725        3     F      NaN    NaN   NaN     NaN      NaN       NaN
# 310698        3   R64      NaN    NaN   NaN     NaN      NaN       NaN
# 310826        3     F      NaN    NaN   NaN     NaN      NaN       NaN
# 319672        3    RR      NaN    NaN   NaN     NaN      NaN       NaN
# 324151        3   R16      NaN    NaN   NaN     NaN      NaN       NaN
# 324196        3   R64      NaN    NaN   NaN     NaN      NaN       NaN
# 324653        3     F      NaN    NaN   NaN     NaN      NaN       NaN
# 327523        3   R16      NaN    NaN   NaN     NaN      NaN       NaN
# 331377        3   R64      NaN    NaN   NaN     NaN      NaN       NaN
# 334693        3     F      NaN    NaN   NaN     NaN      NaN       NaN
# 342199        3     F      NaN    NaN   NaN     NaN      NaN       NaN
# 342896        3   R16      NaN    NaN   NaN     NaN      NaN       NaN
# 344703        3   R16      NaN    NaN   NaN     NaN      NaN       NaN
# 345048        3     F      NaN    NaN   NaN     NaN      NaN       NaN
# 347585        3     F      NaN    NaN   NaN     NaN      NaN       NaN
# 350084        3     F      NaN    NaN   NaN     NaN      NaN       NaN
# 353434        3   R16      NaN    NaN   NaN     NaN      NaN       NaN
# 353780        3   R16      NaN    NaN   NaN     NaN      NaN       NaN
# 358375        3   R32      NaN    NaN   NaN     NaN      NaN       NaN
# 359307        3   R16      NaN    NaN   NaN     NaN      NaN       NaN
# 359336        3     F      NaN    NaN   NaN     NaN      NaN       NaN
# 360046        3     F      NaN    NaN   NaN     NaN      NaN       NaN
# 361760        3     F      NaN    NaN   NaN     NaN      NaN       NaN
# 362257        3   R32      NaN    NaN   NaN     NaN      NaN       NaN
# 364566        3     F      NaN    NaN   NaN     NaN      NaN       NaN
# 367304        3   R16      NaN    NaN   NaN     NaN      NaN       NaN
# 368292        3     F      NaN    NaN   NaN     NaN      NaN       NaN
# 370870        3   R32      NaN    NaN   NaN     NaN      NaN       NaN
# 371052        3   R32      NaN    NaN   NaN     NaN      NaN       NaN
# 371773        3   R16      NaN    NaN   NaN     NaN      NaN       NaN
# 371836        3   R16      NaN    NaN   NaN     NaN      NaN       NaN
#
#         w_2ndWon  w_SvGms  w_bpSaved  w_bpFaced  l_ace  l_df  l_svpt  l_1stIn  \
# 197008       NaN      NaN        NaN        NaN    NaN   NaN     NaN      NaN
# 198716       NaN      NaN        NaN        NaN    NaN   NaN     NaN      NaN
# 199865       NaN      NaN        NaN        NaN    NaN   NaN     NaN      NaN
# 201182       NaN      NaN        NaN        NaN    NaN   NaN     NaN      NaN
# 207976       NaN      NaN        NaN        NaN    NaN   NaN     NaN      NaN
# 211860       NaN      NaN        NaN        NaN    NaN   NaN     NaN      NaN
# 212218       NaN      NaN        NaN        NaN    NaN   NaN     NaN      NaN
# 223765       NaN      NaN        NaN        NaN    NaN   NaN     NaN      NaN
# 234450       NaN      NaN        NaN        NaN    NaN   NaN     NaN      NaN
# 307725       NaN      NaN        NaN        NaN    NaN   NaN     NaN      NaN
# 310698       NaN      NaN        NaN        NaN    NaN   NaN     NaN      NaN
# 310826       NaN      NaN        NaN        NaN    NaN   NaN     NaN      NaN
# 319672       NaN      NaN        NaN        NaN    NaN   NaN     NaN      NaN
# 324151       NaN      NaN        NaN        NaN    NaN   NaN     NaN      NaN
# 324196       NaN      NaN        NaN        NaN    NaN   NaN     NaN      NaN
# 324653       NaN      NaN        NaN        NaN    NaN   NaN     NaN      NaN
# 327523       NaN      NaN        NaN        NaN    NaN   NaN     NaN      NaN
# 331377       NaN      NaN        NaN        NaN    NaN   NaN     NaN      NaN
# 334693       NaN      NaN        NaN        NaN    NaN   NaN     NaN      NaN
# 342199       NaN      NaN        NaN        NaN    NaN   NaN     NaN      NaN
# 342896       NaN      NaN        NaN        NaN    NaN   NaN     NaN      NaN
# 344703       NaN      NaN        NaN        NaN    NaN   NaN     NaN      NaN
# 345048       NaN      NaN        NaN        NaN    NaN   NaN     NaN      NaN
# 347585       NaN      NaN        NaN        NaN    NaN   NaN     NaN      NaN
# 350084       NaN      NaN        NaN        NaN    NaN   NaN     NaN      NaN
# 353434       NaN      NaN        NaN        NaN    NaN   NaN     NaN      NaN
# 353780       NaN      NaN        NaN        NaN    NaN   NaN     NaN      NaN
# 358375       NaN      NaN        NaN        NaN    NaN   NaN     NaN      NaN
# 359307       NaN      NaN        NaN        NaN    NaN   NaN     NaN      NaN
# 359336       NaN      NaN        NaN        NaN    NaN   NaN     NaN      NaN
# 360046       NaN      NaN        NaN        NaN    NaN   NaN     NaN      NaN
# 361760       NaN      NaN        NaN        NaN    NaN   NaN     NaN      NaN
# 362257       NaN      NaN        NaN        NaN    NaN   NaN     NaN      NaN
# 364566       NaN      NaN        NaN        NaN    NaN   NaN     NaN      NaN
# 367304       NaN      NaN        NaN        NaN    NaN   NaN     NaN      NaN
# 368292       NaN      NaN        NaN        NaN    NaN   NaN     NaN      NaN
# 370870       NaN      NaN        NaN        NaN    NaN   NaN     NaN      NaN
# 371052       NaN      NaN        NaN        NaN    NaN   NaN     NaN      NaN
# 371773       NaN      NaN        NaN        NaN    NaN   NaN     NaN      NaN
# 371836       NaN      NaN        NaN        NaN    NaN   NaN     NaN      NaN
#
#         l_1stWon  l_2ndWon  l_SvGms  l_bpSaved  l_bpFaced  winner_rank  \
# 197008       NaN       NaN      NaN        NaN        NaN          1.0
# 198716       NaN       NaN      NaN        NaN        NaN        163.0
# 199865       NaN       NaN      NaN        NaN        NaN          4.0
# 201182       NaN       NaN      NaN        NaN        NaN          NaN
# 207976       NaN       NaN      NaN        NaN        NaN          NaN
# 211860       NaN       NaN      NaN        NaN        NaN          2.0
# 212218       NaN       NaN      NaN        NaN        NaN         55.0
# 223765       NaN       NaN      NaN        NaN        NaN          NaN
# 234450       NaN       NaN      NaN        NaN        NaN          NaN
# 307725       NaN       NaN      NaN        NaN        NaN          3.0
# 310698       NaN       NaN      NaN        NaN        NaN        192.0
# 310826       NaN       NaN      NaN        NaN        NaN          1.0
# 319672       NaN       NaN      NaN        NaN        NaN          NaN
# 324151       NaN       NaN      NaN        NaN        NaN         13.0
# 324196       NaN       NaN      NaN        NaN        NaN         52.0
# 324653       NaN       NaN      NaN        NaN        NaN          9.0
# 327523       NaN       NaN      NaN        NaN        NaN          NaN
# 331377       NaN       NaN      NaN        NaN        NaN          NaN
# 334693       NaN       NaN      NaN        NaN        NaN          1.0
# 342199       NaN       NaN      NaN        NaN        NaN          1.0
# 342896       NaN       NaN      NaN        NaN        NaN         35.0
# 344703       NaN       NaN      NaN        NaN        NaN         50.0
# 345048       NaN       NaN      NaN        NaN        NaN          1.0
# 347585       NaN       NaN      NaN        NaN        NaN          NaN
# 350084       NaN       NaN      NaN        NaN        NaN          3.0
# 353434       NaN       NaN      NaN        NaN        NaN          NaN
# 353780       NaN       NaN      NaN        NaN        NaN          NaN
# 358375       NaN       NaN      NaN        NaN        NaN         50.0
# 359307       NaN       NaN      NaN        NaN        NaN          1.0
# 359336       NaN       NaN      NaN        NaN        NaN          1.0
# 360046       NaN       NaN      NaN        NaN        NaN          1.0
# 361760       NaN       NaN      NaN        NaN        NaN          1.0
# 362257       NaN       NaN      NaN        NaN        NaN         12.0
# 364566       NaN       NaN      NaN        NaN        NaN          1.0
# 367304       NaN       NaN      NaN        NaN        NaN          8.0
# 368292       NaN       NaN      NaN        NaN        NaN          1.0
# 370870       NaN       NaN      NaN        NaN        NaN          NaN
# 371052       NaN       NaN      NaN        NaN        NaN          NaN
# 371773       NaN       NaN      NaN        NaN        NaN          NaN
# 371836       NaN       NaN      NaN        NaN        NaN          NaN
#
#         winner_rank_points  loser_rank  loser_rank_points league  \
# 197008               296.0         2.0              216.0    wta
# 198716                 4.0       100.0                9.0    wta
# 199865               145.0         5.0              116.0    wta
# 201182                 NaN         NaN                NaN    wta
# 207976                 NaN         NaN                NaN    wta
# 211860              4887.0         1.0             5333.0    wta
# 212218               489.0        62.0              445.0    wta
# 223765                 NaN         NaN                NaN    wta
# 234450                 NaN         NaN                NaN    wta
# 307725              3454.0         7.0             2430.0    wta
# 310698                 6.0        70.0               21.0    wta
# 310826               291.0         5.0              166.0    wta
# 319672                 NaN         NaN                NaN    wta
# 324151                83.0       100.0               15.0    wta
# 324196                32.0         NaN                NaN    wta
# 324653               116.0         7.0              124.0    wta
# 327523                 NaN         NaN                NaN    wta
# 331377                 NaN         NaN                NaN    wta
# 334693               383.0        12.0              110.0    wta
# 342199               269.0         4.0              185.0    wta
# 342896                26.0        98.0               12.0    wta
# 344703                 NaN         NaN                NaN    wta
# 345048                 NaN         4.0                NaN    wta
# 347585                 NaN         NaN                NaN    wta
# 350084               191.0         5.0              135.0    wta
# 353434                 NaN         NaN                NaN    wta
# 353780                 NaN         NaN                NaN    wta
# 358375                 NaN         NaN                NaN    wta
# 359307                 NaN        17.0                NaN    wta
# 359336                 NaN         5.0                NaN    wta
# 360046                 NaN         3.0                NaN    wta
# 361760               283.0         5.0              172.0    wta
# 362257                66.0       118.0               10.0    wta
# 364566               389.0         2.0              234.0    wta
# 367304                70.0        59.0               14.0    wta
# 368292               273.0         6.0              102.0    wta
# 370870                 NaN         NaN                NaN    wta
# 371052                 NaN         NaN                NaN    wta
# 371773                 NaN         NaN                NaN    wta
# 371836                 NaN         NaN                NaN    wta
#
#         winner_ngames  loser_ngames  winner_nsets  delta_w_l_ngames match_type
# 197008             21            17             3                 4  best of 5
# 198716             18             6             3                12  best of 5
# 199865             19             9             3                10  best of 5
# 201182             19             9             3                10  best of 5
# 207976             18            10             3                 8  best of 5
# 211860             23            17             3                 6  best of 5
# 212218             19            11             3                 8  best of 5
# 223765             18            10             3                 8  best of 5
# 234450             25            15             3                10  best of 5
# 307725             19            11             3                 8  best of 5
# 310698             19            11             3                 8  best of 5
# 310826             26            15             3                11  best of 5
# 319672             19             6             3                13  best of 5
# 324151             18             5             3                13  best of 5
# 324196             19             9             3                10  best of 5
# 324653             18             9             3                 9  best of 5
# 327523             19            10             3                 9  best of 5
# 331377             18             8             3                10  best of 5
# 334693             24            17             3                 7  best of 5
# 342199             22            15             3                 7  best of 5
# 342896             18             8             3                10  best of 5
# 344703             18             9             3                 9  best of 5
# 345048             19            12             3                 7  best of 5
# 347585             19             9             3                10  best of 5
# 350084             26            23             3                 3  best of 5
# 353434             19            11             3                 8  best of 5
# 353780             21            15             3                 6  best of 5
# 358375             21            15             3                 6  best of 5
# 359307             19            11             3                 8  best of 5
# 359336             21             9             3                12  best of 5
# 360046             19            11             3                 8  best of 5
# 361760             19             9             3                10  best of 5
# 362257             18             9             3                 9  best of 5
# 364566             21            12             3                 9  best of 5
# 367304             19             7             3                12  best of 5
# 368292             22            14             3                 8  best of 5
# 370870             19            13             3                 6  best of 5
# 371052             19            10             3                 9  best of 5
# 371773             18             7             3                11  best of 5
# 371836             19            10             3                 9  best of 5

# %%
df_matches[df_matches['delta_w_l_ngames'] < -10]
# Out:
#        tourney_id          tourney_name surface draw_size tourney_level  \
# 33516    1982-311          Queen's Club   Grass        64             A
# 96892    1989-329         Tokyo Outdoor    Hard        56             A
# 182078  1975-1041     Houston Satellite     NaN       0.0             W
# 222030  1958-1037                London  Carpet         0             W
# 223259  1958-1117             Wimbledon   Grass         0             G
# 300207  1954-1223     Cortina d'Ampezzo     NaN         0             W
# 338744  1952-1045               Croydon    Clay       0.0             W
# 338931  1952-1058   Birmingham Tally Ho    Clay       0.0             W
# 339957  1952-1168        Wellingborough   Grass       0.0             W
# 368367  1950-1013  Melbourne AUS vs USA   Grass       0.0             W
#
#        tourney_date  match_num  winner_id winner_seed winner_entry  \
# 33516    1982-06-07        250     100517         NaN          NaN
# 96892    1989-04-17         26     100452         NaN            Q
# 182078   1975-01-20         19     201237         NaN          NaN
# 222030   1958-03-10         11     226390         NaN          NaN
# 223259   1958-06-23         22     225269         NaN          NaN
# 300207   1954-08-26          3     226390         NaN          NaN
# 338744   1952-03-31          8     231360         NaN          NaN
# 338931   1952-04-12         27     224085         NaN          NaN
# 339957   1952-08-04          1     230987         NaN          NaN
# 368367   1950-01-13          2     223860         NaN          NaN
#
#                 winner_name winner_hand  winner_ht winner_ioc  winner_age  \
# 33516            Matt Doyle           R      193.0        USA   24.396988
# 96892          Bill Scanlon           R      185.0        USA   32.424367
# 182078         Pam Richmond           U        NaN        USA   24.238193
# 222030  Patricia Ward Hales           U        NaN        GBR   29.029432
# 223259        Thelma Lister           U        NaN        GBR         NaN
# 300207  Patricia Ward Hales           U        NaN        GBR   25.492129
# 338744            Mrs Sharp           U        NaN        GBR         NaN
# 338931    Jean Walker Smith           R        NaN        GBR   28.071184
# 339957        Betty Wilford           U        NaN        GBR   24.186174
# 368367        Louise Brough           R        NaN        USA   26.844627
#
#         loser_id loser_seed loser_entry       loser_name loser_hand  loser_ht  \
# 33516     100553        NaN         NaN     Nduka Odizor          R     183.0
# 96892     101138       16.0         NaN         Pat Cash          R     183.0
# 182078    200265        NaN         NaN   Lindsey Beaven          U       NaN
# 222030    224744        NaN         NaN  Billie Woodgate          U       NaN
# 223259    225526        NaN           Q    Bobbie Wilson          U       NaN
# 300207    200865        NaN         NaN    Heather Segal          U       NaN
# 338744    230753        NaN         NaN        Jill Sole          U       NaN
# 338931    230083        NaN         NaN      Joy Mottram          U       NaN
# 339957    225598        NaN         NaN         Jean Bee          U       NaN
# 368367    231703        NaN         NaN      Joyce Fitch          U       NaN
#
#        loser_ioc  loser_age         score  best_of round  minutes  w_ace  \
# 33516        NGR  23.827515  7-6 4-6 1-19        3   R64      NaN    NaN
# 96892        AUS  23.890486  2-4 0-30 RET        3   R32      NaN    NaN
# 182078       GBR  25.051335    7-5 4-66-3        3    QF      NaN    NaN
# 222030       GBR  32.865161       6-46 -1        3   R32      NaN    NaN
# 223259       GBR        NaN    6-4 7-97-5        3  R128      NaN    NaN
# 300207       RSA  23.088296       6-46 -3        3    SF      NaN    NaN
# 338744       GBR        NaN       6-46 -2        3   R32      NaN    NaN
# 338931       GBR  24.060233   6-1 3-6 -63        3     F      NaN    NaN
# 339957       GBR        NaN        6-46-4        3     F      NaN    NaN
# 368367       AUS  27.780972   5-7 6-1 -63        3    RR      NaN    NaN
#
#         w_df  w_svpt  w_1stIn  w_1stWon  w_2ndWon  w_SvGms  w_bpSaved  \
# 33516    NaN     NaN      NaN       NaN       NaN      NaN        NaN
# 96892    NaN     NaN      NaN       NaN       NaN      NaN        NaN
# 182078   NaN     NaN      NaN       NaN       NaN      NaN        NaN
# 222030   NaN     NaN      NaN       NaN       NaN      NaN        NaN
# 223259   NaN     NaN      NaN       NaN       NaN      NaN        NaN
# 300207   NaN     NaN      NaN       NaN       NaN      NaN        NaN
# 338744   NaN     NaN      NaN       NaN       NaN      NaN        NaN
# 338931   NaN     NaN      NaN       NaN       NaN      NaN        NaN
# 339957   NaN     NaN      NaN       NaN       NaN      NaN        NaN
# 368367   NaN     NaN      NaN       NaN       NaN      NaN        NaN
#
#         w_bpFaced  l_ace  l_df  l_svpt  l_1stIn  l_1stWon  l_2ndWon  l_SvGms  \
# 33516         NaN    NaN   NaN     NaN      NaN       NaN       NaN      NaN
# 96892         NaN    NaN   NaN     NaN      NaN       NaN       NaN      NaN
# 182078        NaN    NaN   NaN     NaN      NaN       NaN       NaN      NaN
# 222030        NaN    NaN   NaN     NaN      NaN       NaN       NaN      NaN
# 223259        NaN    NaN   NaN     NaN      NaN       NaN       NaN      NaN
# 300207        NaN    NaN   NaN     NaN      NaN       NaN       NaN      NaN
# 338744        NaN    NaN   NaN     NaN      NaN       NaN       NaN      NaN
# 338931        NaN    NaN   NaN     NaN      NaN       NaN       NaN      NaN
# 339957        NaN    NaN   NaN     NaN      NaN       NaN       NaN      NaN
# 368367        NaN    NaN   NaN     NaN      NaN       NaN       NaN      NaN
#
#         l_bpSaved  l_bpFaced  winner_rank  winner_rank_points  loser_rank  \
# 33516         NaN        NaN         82.0                 NaN         NaN
# 96892         NaN        NaN        236.0                 NaN        55.0
# 182078        NaN        NaN          NaN                 NaN         NaN
# 222030        NaN        NaN          NaN                 NaN         NaN
# 223259        NaN        NaN          NaN                 NaN         NaN
# 300207        NaN        NaN          NaN                 NaN         NaN
# 338744        NaN        NaN          NaN                 NaN         NaN
# 338931        NaN        NaN          NaN                 NaN         NaN
# 339957        NaN        NaN          NaN                 NaN         NaN
# 368367        NaN        NaN          NaN                 NaN         NaN
#
#         loser_rank_points league  winner_ngames  loser_ngames  winner_nsets  \
# 33516                 NaN    atp             12            31             1
# 96892                 NaN    atp              2            34             0
# 182078                NaN    wta             11            71             1
# 222030                NaN    wta              6            47             0
# 223259                NaN    wta             13           101             1
# 300207                NaN    wta              6            49             0
# 338744                NaN    wta              6            48             0
# 338931                NaN    wta              9            70             1
# 339957                NaN    wta              6            46             0
# 368367                NaN    wta             11            71             1
#
#         delta_w_l_ngames match_type
# 33516                -19  best of 3
# 96892                -32  best of 3
# 182078               -60  best of 3
# 222030               -41  best of 3
# 223259               -88  best of 3
# 300207               -43  best of 3
# 338744               -42  best of 3
# 338931               -61  best of 3
# 339957               -40  best of 3
# 368367               -60  best of 3

# %%
df_matches[df_matches['delta_w_l_ngames'] > 30]
# Out:
#        tourney_id       tourney_name surface draw_size tourney_level  \
# 187552  1960-1102             Barnes   Grass       0.0             W
# 193630  1962-1166  Manchester-On-Sea   Grass       0.0             W
# 205084  1977-1073       Buenos Aires     NaN       0.0             W
# 230044  1970-1162           Budapest    Clay       0.0             W
# 329091  1980-1072              Lecce    Clay       0.0             W
# 340133  1952-1195           Istanbul    Clay       0.0             W
# 345736  1985-1028    Wimbledon Plate   Grass         0             W
# 357438  1951-1170              Dubbo    Clay         0             W
# 357511  1951-1181           Brisbane   Grass         0             W
#
#        tourney_date  match_num  winner_id winner_seed winner_entry  \
# 187552   1960-05-30          8     224616         NaN          NaN
# 193630   1962-08-13         19     212637         NaN          NaN
# 205084   1977-10-10          1     200962         NaN          NaN
# 230044   1970-07-20         22     200144         NaN          NaN
# 329091   1980-07-14          4     201042         NaN          NaN
# 340133   1952-08-22          4     200858         NaN          NaN
# 345736   1985-07-01         20     200463         6.0          NaN
# 357438   1951-09-07          1     224956         NaN          NaN
# 357511   1951-10-29          3     230944         NaN          NaN
#
#               winner_name winner_hand  winner_ht winner_ioc  winner_age  \
# 187552  Rosemary Deloford           U        NaN        USA         NaN
# 193630      Deidre Keller         NaN        NaN        GBR   22.108145
# 205084   Patricia Medrado           U        NaN        BRA   20.870637
# 230044     Margaret Court           R        NaN        AUS   28.010951
# 329091      Andrea Tiezzi           U        NaN        ARG   15.630390
# 340133      Dorothy Knode           U        NaN        USA   27.137577
# 345736     Terry Holladay           U        NaN        USA   29.590691
# 357438        Mary Hawton           R        NaN        AUS   27.006160
# 357511  Lavinia Singleton           U        NaN        AUS   33.511294
#
#         loser_id loser_seed loser_entry            loser_name loser_hand  \
# 187552    224258        NaN         NaN                M Bull        NaN
# 193630    223947        NaN         NaN           Gwyn Thomas          U
# 205084    200961        NaN         NaN  Ivanna Madruga Osses          U
# 230044    200785        NaN         NaN       Vlasta Kodesova          U
# 329091    229454        NaN         NaN       Giulia Collodel          U
# 340133    231591        NaN         NaN    Bahtiye Mursaloglu          U
# 345736    200462        NaN         NaN      Belinda Cordwell          U
# 357438    228393        NaN         NaN          Esme Ashford          U
# 357511    231392        NaN         NaN         Edie Niemeyer          U
#
#         loser_ht loser_ioc  loser_age          score  best_of round  minutes  \
# 187552       NaN       GBR        NaN        6-1 601        3   R16      NaN
# 193630       NaN       USA  22.094456  110-8 4-6 6-2        3   R16      NaN
# 205084       NaN       ARG  16.700890       61 36 64        3     F      NaN
# 230044       NaN       CZE  26.316222          62 63        3     F      NaN
# 329091       NaN       ITA        NaN     75 4-6 6-4        3   R32      NaN
# 340133       NaN       TUR        NaN         61 6-3        3     F      NaN
# 345736       NaN       NZL  19.775496         76 6-3        3   R32      NaN
# 357438       NaN       AUS  34.833676          62 63        3     F      NaN
# 357511       NaN       AUS        NaN       16 63 62        3     F      NaN
#
#         w_ace  w_df  w_svpt  w_1stIn  w_1stWon  w_2ndWon  w_SvGms  w_bpSaved  \
# 187552    NaN   NaN     NaN      NaN       NaN       NaN      NaN        NaN
# 193630    NaN   NaN     NaN      NaN       NaN       NaN      NaN        NaN
# 205084    NaN   NaN     NaN      NaN       NaN       NaN      NaN        NaN
# 230044    NaN   NaN     NaN      NaN       NaN       NaN      NaN        NaN
# 329091    NaN   NaN     NaN      NaN       NaN       NaN      NaN        NaN
# 340133    NaN   NaN     NaN      NaN       NaN       NaN      NaN        NaN
# 345736    NaN   NaN     NaN      NaN       NaN       NaN      NaN        NaN
# 357438    NaN   NaN     NaN      NaN       NaN       NaN      NaN        NaN
# 357511    NaN   NaN     NaN      NaN       NaN       NaN      NaN        NaN
#
#         w_bpFaced  l_ace  l_df  l_svpt  l_1stIn  l_1stWon  l_2ndWon  l_SvGms  \
# 187552        NaN    NaN   NaN     NaN      NaN       NaN       NaN      NaN
# 193630        NaN    NaN   NaN     NaN      NaN       NaN       NaN      NaN
# 205084        NaN    NaN   NaN     NaN      NaN       NaN       NaN      NaN
# 230044        NaN    NaN   NaN     NaN      NaN       NaN       NaN      NaN
# 329091        NaN    NaN   NaN     NaN      NaN       NaN       NaN      NaN
# 340133        NaN    NaN   NaN     NaN      NaN       NaN       NaN      NaN
# 345736        NaN    NaN   NaN     NaN      NaN       NaN       NaN      NaN
# 357438        NaN    NaN   NaN     NaN      NaN       NaN       NaN      NaN
# 357511        NaN    NaN   NaN     NaN      NaN       NaN       NaN      NaN
#
#         l_bpSaved  l_bpFaced  winner_rank  winner_rank_points  loser_rank  \
# 187552        NaN        NaN          NaN                 NaN         NaN
# 193630        NaN        NaN          NaN                 NaN         NaN
# 205084        NaN        NaN          NaN                 NaN         NaN
# 230044        NaN        NaN          NaN                 NaN         NaN
# 329091        NaN        NaN          NaN                 NaN         NaN
# 340133        NaN        NaN          NaN                 NaN         NaN
# 345736        NaN        NaN          NaN                 NaN         NaN
# 357438        NaN        NaN          NaN                 NaN         NaN
# 357511        NaN        NaN          NaN                 NaN         NaN
#
#         loser_rank_points league  winner_ngames  loser_ngames  winner_nsets  \
# 187552                NaN    wta            607             1             1
# 193630                NaN    wta            120            16             2
# 205084                NaN    wta            161             0             0
# 230044                NaN    wta            125             0             0
# 329091                NaN    wta             85            10             1
# 340133                NaN    wta             67             3             1
# 345736                NaN    wta             82             3             1
# 357438                NaN    wta            125             0             0
# 357511                NaN    wta            141             0             0
#
#         delta_w_l_ngames match_type
# 187552               606  best of 3
# 193630               104  best of 3
# 205084               161  best of 3
# 230044               125  best of 3
# 329091                75  best of 3
# 340133                64  best of 3
# 345736                79  best of 3
# 357438               125  best of 3
# 357511               141  best of 3

# %% [markdown]
# ### The Most Successful Male Players NOT to have won a Grand Slam <a class="anchor" id="111-bullet"></a>
#
# In tennis, the slam winners get all the glory and the $$$. But there are players who have accomplished a lot in the sport while not managing to win a GS - let's find the most successful such male player!
#
# Let's consider the following factors:
# - No. of titles won
# - Best career rank achieved
# - No. of top 10 wins

# %%
df_players_male_title_wf_non_gs = df_players_male_title_wf[df_players_male_title_wf['n_titles_gs']==0]

# %%
fig = px.scatter(df_players_male_title_wf_non_gs, y='n_titles', x='n_top10_wins', size='best_rank',
                hover_data=['name'],
                labels={'n_titles': 'No. of titles won', 'n_top10_wins': 'No. of top-10 wins', 'big_3': 'Big 3 player?', 
                       'best_rank': 'Best Career Rank'},
                title='Best Male Players Not to have won Grand Slams')

# Display interactive image as static due to constraints around rendering interactive images in webpages and github
# fig.show("notebook")
Image(fig.to_image(format="png", width=1000, height=500, engine="kaleido"))

# %% [markdown]
# **The best player based on no. of titles won, no. of top 10 wins and best career rank is David Ferrer, by far! Thomas Enquist, Tommy Hass, Nikolay Davydenko and Thomas Berdych are other successful players not to have wn GS's.**
#
# **Interestingly, it seems there has only ever been one non-GS winner to have been world #1, Marcelo Rios!**
